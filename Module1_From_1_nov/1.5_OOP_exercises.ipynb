# %% [markdown]
# # 1.5: Object-Oriented Programming (OOP) - Exercises

# %% [markdown]
# ### Exercise 1: Basic Class and Object

# %%
class Car:
    wheels = 4

    def drive(self):
        print('The car is moving')
    
    def stop(self):
        print('The car has stopped')

my_car = Car()
my_car.drive()
my_car.stop()
# Out:
# The car is moving
# The car has stopped

# %% [markdown]
# ### Exercise 2: The __init__ Method

# %%
class Car:
    wheels = 4

    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def describe(self):
        return f'This is {self.year} {self.model}'

my_car = Car('122', 'Ford Mustang', 2020)
my_car.describe()
# Out:
# 'This is 2020 Ford Mustang'

# %% [markdown]
# ### Basic Inheritance

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year, battery_size):
        super().__init__(make, model, year)
        self.battery_size = battery_size

my_E_car = ElectricCar('dsj', 'Model2', 2021, 200)
my_E_car.describe()
# Out:
# 'This is 2021 Model2'

# %% [markdown]
# # Exercise 3: Basic Inheritance

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year, battery_size):
        super().__init__(make, model, year)
        self.battery_size = battery_size

My_car = ElectricCar('Make1', 'Model1', 2020, 120)
My_car.describe()
# Out:
# 'This is 2020 Model1'

# %% [markdown]
# # Exercise 4: Method Overriding

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year, battery_size):
        super().__init__(make, model, year)
        self.battery_size = battery_size

    def describe(self):
        return f'{super().describe()} with a {self.battery_size}kWh battery.'
    
    def refuel(self):
        print('The car is charging.')
My_car = ElectricCar('Make1', 'Model1', 2020, 120)
My_car.describe()
# Out:
# 'This is 2020 Model1 with a 120kWh battery.'

# %% [markdown]
# # Eercise 5: Polymorphism

# %%
class FuelCar(Car):
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
    def refuel(self):
        print('The car is refueling')


My_F_car = FuelCar('Make1', 'Model1', 2020)
for i in [My_car, My_F_car]:
    i.refuel()
# Out:
# The car is charging.
# The car is refueling

# %% [markdown]
# # Exercise 6: Encapsulation

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
    
    def withdraw(self, amount):
        self.__balance -= amount
        if self.__balance <= 0:
            self.__balance = 0
    
    def get_balance(self):
        return self.__balance
    
my_account = BankAccount('Me', 100000)
my_account.deposit(200)
print(my_account.get_balance())
my_account.withdraw(100000)
print(my_account.get_balance())
my_account.withdraw(300)
print(my_account.get_balance())
# Out:
# 100200
# 200
# 0

# %% [markdown]
# # Exercise 7: Line Class

# %%
class Line:
    def __init__(self, point1, point2):
        self.point1 = point1
        self.point2 = point2
    
    def calculate_length(self):
        return ((self.point2[0] - self.point1[0]) ** 2 + (self.point2[1] - self.point1[1]) ** 2) ** (1/2)
    
    def calculate_slope(self):
        return (self.point2[1] - self.point1[1]) / (self.point2[0] - self.point1[0])

my_line = Line((0, 0), (3, 4))
print(my_line.calculate_length())
print(my_line.calculate_slope())
# Out:
# 5.0
# 1.3333333333333333

# %% [markdown]
# # Exercise 8: Rectangle Class

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def calculate_area(self):
        return self.width * self.height
    
    def calculate_perimeter(self):
        return 2 * (self.width + self.height)
    
my_rect = Rectangle(2, 3)
my_rect.calculate_area()
my_rect.calculate_perimeter()
# Out:
# 10

# %% [markdown]
# # Exercise 9: Cylinder Class

# %%
class Cylinder:
    PI = 3.14
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def calculate_volume(self):
        return Cylinder.PI * self.radius ** 2 * self.height
    
    def calulate_surface_area(self):
        return 2 * Cylinder.PI * self.radius * (self.radius + self.height)
    
my_cyldr = Cylinder(10, 2)
print(my_cyldr.calculate_volume())
print(my_cyldr.calulate_surface_area())
# Out:
# 628.0
# 753.6

# %% [markdown]
# # Exercise 10: __str__ and __len__

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return f"'{self.title}' by {self.author}, {self.pages} pages."
    
    def __len__(self):
        return self.pages

my_book = Book('The Hobbit', 'J.R.R. Tolkien', 310)
print(my_book)
print(len(my_book))
# Out:
# 'The Hobbit' by J.R.R. Tolkien, 310 pages.
# 310

# %% [markdown]
# # Exercise 11: Using @dataclass

# %%
from dataclasses import dataclass

@dataclass
class Book:
    title : str
    author : str
    pages : int

my_book = Book('Title1', 'Author1', 100)
your_book = Book('Title2', 'Author2', 100)

print(my_book)
# Out:
# Book(title='Title1', author='Author1', pages=100)

# %% [markdown]
# ### Exercise 12: @staticmethod

# %%
class StringUtils:
    @staticmethod
    def reverse(text):
        return text[::-1]
    
print(StringUtils.reverse('abc'))
# Out:
# cba

# %% [markdown]
# ### Exercise 13: @classmethod

# %%
class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model
    @classmethod
    def from_string(cls, car_string):
        make, model = car_string.split('-')
        return cls(make, model)

car = Car.from_string('Toyota-Corolla')
print(car.make)
print(car.model)
# Out:
# Toyota
# Corolla

# %% [markdown]
# ### Exercise 14: @property

# %%
class Person:
    def __init__(self, first_name, last_name):
        self.__first_name = first_name
        self.__last_name = last_name
    @property
    def full_name(self):
        return self.__first_name + ' ' + self.__last_name
    
    @full_name.setter
    def full_name(self, full_name):
        print('Setting Values')
        try:
            self.__first_name, self.__last_name = full_name.split(' ')
        except:
            raise ValueError('Enter valid Full Name')
    
person = Person('FirstName', 'LastName')
print(person.full_name)
person.full_name = 'First Last'
print(person.full_name)
# Out:
# FirstName LastName
# Setting Values
# First Last

# %% [markdown]
# ### Abstraction

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return 'Meow'
    
dog = Dog()
dog.sound()
# Out:
# 'Bark'

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    def __init__(self, color):
        self.color = color

    @abstractmethod
    def area(self):
        pass

    def describe(self):
        return f'This shape is {self.color}'
    
class Circle(Shape):
    PI = 3.14
    def __init__(self, radius, color):
        super().__init__(color)
        self.radius = radius
    
    def area(self):
        return Circle.PI * self.radius ** 2
    
circle = Circle(10, 'green')
print(circle.describe())
print(circle.area())
# Out:
# This shape is green
# 314.0
