# %%
print(r"C:\Users\konta\Documents\DIV_Academy\text.txt")
# Out:
# C:\Users\konta\Documents\DIV_Academy\text.txt

# %%
from pathlib import Path
text_path = Path(r"C:\Users\konta\Documents\DIV_Academy\text.txt")
print(text_path.read_text())
current_dir = Path.cwd()
home_dir = Path.home()
print(current_dir)
print(home_dir)

rel_path = Path("../practice_functions_15_nov.ipynb")
print(rel_path.exists())
print(rel_path.absolute())
print('----')
print(rel_path.resolve())
print(rel_path.suffix)
print(rel_path.stem)
print(text_path.is_file())
print(text_path.is_fifo())

new_folder = current_dir / 'New_folder'
print(new_folder)
print(new_folder.exists())
new_folder.mkdir(exist_ok=True)

new_file = new_folder / 'New_file.txt'
print(new_file.exists())
new_file.write_text('content of new file')
new_file.write_text('Second line\nI am so happy')

print(new_file.read_text())
# Out:
# False
# c:\Users\konta\Documents\DIV_Academy\Module1(From_1_nov)\..\practice_functions_15_nov.ipynb
# ----
# C:\Users\konta\Documents\DIV_Academy\practice_functions_15_nov.ipynb
# .ipynb
# practice_functions_15_nov

# %%
with new_file.open('r') as f:
    l = f.readline()
print(l)
# Out:
# Second line

# %%
csv_path = Path(r'C:\Users\konta\Documents\DIV_Academy\car-sales.csv')

csv_path.exists()

with csv_path.open('r') as f:
    for line in f.readlines():
        print(line)
# Out:
# Make,Colour,Odometer (KM),Doors,Price
#
# Toyota,White,150043,4,"$4,000.00"
#
# Honda,Red,87899,4,"$5,000.00"
#
# Toyota,Blue,32549,3,"$7,000.00"
#
# BMW,Black,11179,5,"$22,000.00"
#
# Nissan,White,213095,4,"$3,500.00"
#
# Toyota,Green,99213,4,"$4,500.00"
#
# Honda,Blue,45698,4,"$7,500.00"
#
# Honda,Blue,54738,4,"$7,000.00"
#
# Toyota,White,60000,4,"$6,250.00"
#
# Nissan,White,31600,4,"$9,700.00"
