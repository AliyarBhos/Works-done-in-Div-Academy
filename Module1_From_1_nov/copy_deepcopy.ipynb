# %%
x = ['a', 'b', 'c']
y = x.copy()
x[0] = 'z'
print(x)
print(y)
# Out:
# ['z', 'b', 'c']
# ['a', 'b', 'c']

# %%
from copy import deepcopy
x = [['a', 'b', 'c'], ['d', 'e', 'f']]
# y = x.copy()
# x[0][0] = 'z'

# print(x)
# print(y)

y = deepcopy(x)
x[0][0] = 'z'
print(x)
print(y)
# Out:
# [['z', 'b', 'c'], ['d', 'e', 'f']]
# [['a', 'b', 'c'], ['d', 'e', 'f']]
