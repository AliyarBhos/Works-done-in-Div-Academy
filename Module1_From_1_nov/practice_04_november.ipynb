# %%
2 ** 5

# %%
21 % 4

# %%
21 // 4

# %%
20 // 4

# %%
20 / 4

# %%
(10 + 5) * 3

# %% [markdown]
# ## Header

# %%
10 + 5 * 3
# Out:
# 32

# %%
a = 50 > 100
a
# Out:
# False

# %%
a = 33 == 33.0
a
# Out:
# True

# %%
a = 'hello' == 'world'
a
# Out:
# False

# %%
a = len('python') >= 5
a
# Out:
# True

# %%
city = 'New York'
print(city)
city = 'London'
print(city)
# Out:
# New York
# London

# %%
score = 100
score -= 25
score *= 2
score

# %%
price_str = '25.99'
Float = float(price_str)
String = str(3)
String

print(String + 'items')
# Out:
# '3'

# %%
first = 'JJN'
last = 'HJNJ'
full = first + last
full
separator = '-'*30
print(full)
print(separator)
# Out:
# JJNHJNJ
# ------------------------------

# %%
print(f'The file is located at:\nC:\\Users\\new_folder\\tabbed_file.txt')
# Out:
# The file is located at:
# C:\Users\new_folder\tabbed_file.txt

# %%
s = "Programming is fun!"
print(s[4], s[-1], s[11:13])
print(s[3:7])
print(s[::-1])
# Out:
# r !  i
# gram
# !nuf si gnimmargorP

# %%
tweet = "  WOW, what a great game! #sports #python  "
print(tweet.lower())
print(tweet.strip())

tweet.replace('#python', "#DataScience").strip()
print(tweet.split())
# Out:
#   wow, what a great game! #sports #python
# WOW, what a great game! #sports #python
# ['WOW,', 'what', 'a', 'great', 'game!', '#sports', '#python']

# %%
user_name = input("What's Your name")
print(f'Hello {user_name}')
# Out:
# Hello Ell

# %%
current_year = int(input('Enter current year: '))
birth_year  = int(input('Enter birth year: '))

print(f'Your age is {current_year - birth_year}')
# Out:
# Your age is 19

# %%
item = "Laptop"
price = 1200.50
quantity = 2
total_cost = price * quantity
print(f'Item: {item}, Quantity: {quantity}, Total Cost: ${total_cost:,.2f}')
# Out:
# Item: Laptop, Quantity: 2, Total Cost: $2,401.00
