# %%
import pandas as pd

# %%
ages = [10, 20, 30, 40]

s1 = pd.Series(data=ages, index=['Person1', 'Person2', 'Person3', 'Person4'])
s2 = pd.Series(
    [179,  180, 170, 160],
    index=['Person1', 'Person2', 'Person3', 'Person4']
)

df = pd.DataFrame({
    'age': s1,
    'height': s2
})

df
# Out:
#          age  height
# Person1   10     179
# Person2   20     180
# Person3   30     170
# Person4   40     160

# %%
from pathlib import Path

csv_path = Path(r'C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\world_population.csv')

df = pd.read_csv(csv_path)
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
print(df['CCA3'])
df2 = df[[
    'CCA3', 'Country', 'Capital', 'Continent', '2022 Population', '2020 Population', '2015 Population'
    ]].copy()

df2.head(3)
# Out:
# 0      AFG
# 1      ALB
# 2      DZA
# 3      ASM
# 4      AND
#       ...
# 229    WLF
# 230    ESH
# 231    YEM
# 232    ZMB
# 233    ZWE
# Name: CCA3, Length: 234, dtype: object
#   CCA3      Country  Capital Continent  2022 Population  2020 Population  \
# 0  AFG  Afghanistan    Kabul      Asia       41128771.0       38972230.0
# 1  ALB      Albania   Tirana    Europe        2842321.0        2866849.0
# 2  DZA      Algeria  Algiers    Africa       44903225.0       43451666.0
#
#    2015 Population
# 0       33753499.0
# 1        2882481.0
# 2       39543154.0

# %%
df3 = df2.set_index(['Continent', 'CCA3']).sort_index()
df3
# Out:
#                          Country      Capital  2022 Population  \
# Continent     CCA3
# Africa        AGO         Angola       Luanda       35588987.0
#               BDI        Burundi    Bujumbura       12889576.0
#               BEN          Benin   Porto-Novo       13352864.0
#               BFA   Burkina Faso  Ouagadougou       22673762.0
#               BWA       Botswana     Gaborone        2630296.0
# ...                          ...          ...              ...
# South America PER           Peru         Lima       34049588.0
#               PRY       Paraguay     Asunción        6780744.0
#               SUR       Suriname   Paramaribo         618040.0
#               URY        Uruguay   Montevideo        3422794.0
#               VEN      Venezuela      Caracas       28301696.0
#
#                     2020 Population  2015 Population
# Continent     CCA3
# Africa        AGO        33428485.0       28127721.0
#               BDI        12220227.0       10727148.0
# ...

# %%
df3['Country']
# Out:
# Continent      CCA3
# Africa         AGO           Angola
#                BDI          Burundi
#                BEN            Benin
#                BFA     Burkina Faso
#                BWA         Botswana
#                            ...
# South America  PER             Peru
#                PRY         Paraguay
#                SUR         Suriname
#                URY          Uruguay
#                VEN        Venezuela
# Name: Country, Length: 234, dtype: object

# %%
#df3.loc['Africa'].loc['AGO']
df3.loc[('Africa', 'AGO')]
# Out:
# Country                Angola
# Capital                Luanda
# 2022 Population    35588987.0
# 2020 Population    33428485.0
# 2015 Population    28127721.0
# Name: (Africa, AGO), dtype: object

# %%
df3.iloc[0]
# Out:
# ['CCA3',
#  'Country',
#  'Capital',
#  'Continent',
#  '2022 Population',
#  '2020 Population',
#  '2015 Population']

# %%
# df3.columns = [
#     ['General', 'General', 'Population', 'Population', 'Population'], 
#     ['Country', 'Capital', '2022 Population', '2020 Population', '2015 Population']
# ]
# df3
level0_cols = ['Population' if 'Population' in col else 'General' for col in df3.columns.tolist()]
level1_cols = df3.columns.tolist()
df3.columns = [
    level0_cols,  
    level1_cols
]
df3
# Out:
#                          General                   Population                  \
#                          Country      Capital 2022 Population 2020 Population
# Continent     CCA3
# Africa        AGO         Angola       Luanda      35588987.0      33428485.0
#               BDI        Burundi    Bujumbura      12889576.0      12220227.0
#               BEN          Benin   Porto-Novo      13352864.0      12643123.0
#               BFA   Burkina Faso  Ouagadougou      22673762.0      21522626.0
#               BWA       Botswana     Gaborone       2630296.0       2546402.0
# ...                          ...          ...             ...             ...
# South America PER           Peru         Lima      34049588.0      33304756.0
#               PRY       Paraguay     Asunción       6780744.0       6618695.0
#               SUR       Suriname   Paramaribo        618040.0        607065.0
#               URY        Uruguay   Montevideo       3422794.0       3429086.0
# ...

# %%
df3.to_excel('World_Population.xlsx')

# %%
df3[('General', 'Country')]
# Out:
# Continent      CCA3
# Africa         AGO           Angola
#                BDI          Burundi
#                BEN            Benin
#                BFA     Burkina Faso
#                BWA         Botswana
#                            ...
# South America  PER             Peru
#                PRY         Paraguay
#                SUR         Suriname
#                URY          Uruguay
#                VEN        Venezuela
# Name: (General, Country), Length: 234, dtype: object

# %%
df4 = df3.droplevel(level=0) #by default -> rows

df4.droplevel(level=0, axis='columns')
# Out:
#            Country      Capital  2022 Population  2020 Population  \
# CCA3
# AGO         Angola       Luanda       35588987.0       33428485.0
# BDI        Burundi    Bujumbura       12889576.0       12220227.0
# BEN          Benin   Porto-Novo       13352864.0       12643123.0
# BFA   Burkina Faso  Ouagadougou       22673762.0       21522626.0
# BWA       Botswana     Gaborone        2630296.0        2546402.0
# ...            ...          ...              ...              ...
# PER           Peru         Lima       34049588.0       33304756.0
# PRY       Paraguay     Asunción        6780744.0        6618695.0
# SUR       Suriname   Paramaribo         618040.0         607065.0
# URY        Uruguay   Montevideo        3422794.0        3429086.0
# VEN      Venezuela      Caracas       28301696.0       28490453.0
#
#       2015 Population
# CCA3
# AGO        28127721.0
# BDI        10727148.0
# BEN        10932783.0
# BFA        18718019.0
# BWA         2305171.0
# ...

# %%
df4.T
# Out:
# CCA3                               AGO         BDI         BEN           BFA  \
# General    Country              Angola     Burundi       Benin  Burkina Faso
#            Capital              Luanda   Bujumbura  Porto-Novo   Ouagadougou
# Population 2022 Population  35588987.0  12889576.0  13352864.0    22673762.0
#            2020 Population  33428485.0  12220227.0  12643123.0    21522626.0
#            2015 Population  28127721.0  10727148.0  10932783.0    18718019.0
#
# CCA3                              BWA                       CAF           CIV  \
# General    Country           Botswana  Central African Republic   Ivory Coast
#            Capital           Gaborone                    Bangui  Yamoussoukro
# Population 2022 Population  2630296.0                 5579144.0    28160542.0
#            2020 Population  2546402.0                 5343020.0    26811790.0
#            2015 Population  2305171.0                 4819333.0    23596741.0
#
# ...

# %%
df4.rename({'Capital': 'Capitals'}, axis='columns')
# Out:
#            General                   Population                  \
#            Country     Capitals 2022 Population 2020 Population
# CCA3
# AGO         Angola       Luanda      35588987.0      33428485.0
# BDI        Burundi    Bujumbura      12889576.0      12220227.0
# BEN          Benin   Porto-Novo      13352864.0      12643123.0
# BFA   Burkina Faso  Ouagadougou      22673762.0      21522626.0
# BWA       Botswana     Gaborone       2630296.0       2546402.0
# ...            ...          ...             ...             ...
# PER           Peru         Lima      34049588.0      33304756.0
# PRY       Paraguay     Asunción       6780744.0       6618695.0
# SUR       Suriname   Paramaribo        618040.0        607065.0
# URY        Uruguay   Montevideo       3422794.0       3429086.0
# VEN      Venezuela      Caracas      28301696.0      28490453.0
#
#
#      2015 Population
# CCA3
# AGO       28127721.0
# BDI       10727148.0
# BEN       10932783.0
# BFA       18718019.0
# ...

# %%
# df4.set_index('General')
# df4
df4.reset_index(drop=True)
# Out:
#           General                   Population
#           Country      Capital 2022 Population 2020 Population 2015 Population
# 0          Angola       Luanda      35588987.0      33428485.0      28127721.0
# 1         Burundi    Bujumbura      12889576.0      12220227.0      10727148.0
# 2           Benin   Porto-Novo      13352864.0      12643123.0      10932783.0
# 3    Burkina Faso  Ouagadougou      22673762.0      21522626.0      18718019.0
# 4        Botswana     Gaborone       2630296.0       2546402.0       2305171.0
# ..            ...          ...             ...             ...             ...
# 229          Peru         Lima      34049588.0      33304756.0      30711863.0
# 230      Paraguay     Asunción       6780744.0       6618695.0       6177950.0
# 231      Suriname   Paramaribo        618040.0        607065.0        575475.0
# 232       Uruguay   Montevideo       3422794.0       3429086.0       3402818.0
# ...

# %%
df4.reset_index()
# Out:
#     CCA3       General                   Population                  \
#                Country      Capital 2022 Population 2020 Population
# 0    AGO        Angola       Luanda      35588987.0      33428485.0
# 1    BDI       Burundi    Bujumbura      12889576.0      12220227.0
# 2    BEN         Benin   Porto-Novo      13352864.0      12643123.0
# 3    BFA  Burkina Faso  Ouagadougou      22673762.0      21522626.0
# 4    BWA      Botswana     Gaborone       2630296.0       2546402.0
# ..   ...           ...          ...             ...             ...
# 229  PER          Peru         Lima      34049588.0      33304756.0
# 230  PRY      Paraguay     Asunción       6780744.0       6618695.0
# 231  SUR      Suriname   Paramaribo        618040.0        607065.0
# 232  URY       Uruguay   Montevideo       3422794.0       3429086.0
# 233  VEN     Venezuela      Caracas      28301696.0      28490453.0
#
#
#     2015 Population
# 0        28127721.0
# 1        10727148.0
# ...

# %%
# %pip install sqlalchemy psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.7 MB 6.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 6.3 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
from sqlalchemy import create_engine, inspect
import pandas as pd

# %%
username = 'divread'
password = 'div123'
host = '65.109.6.168'
database = 'world'

engine = create_engine(f'postgresql://{username}:{password}@{host}/{database}')
engine
# Out:
# Engine(postgresql://divread:***@65.109.6.168/world)

# %%
table_name = 'country'

df_table = pd.read_sql_table(table_name, con=engine)
df_table
# Out:
#     code                                          name      continent  \
# 0    AFG                                   Afghanistan           Asia
# 1    NLD                                   Netherlands         Europe
# 2    ANT                          Netherlands Antilles  North America
# 3    ALB                                       Albania         Europe
# 4    DZA                                       Algeria         Africa
# ..   ...                                           ...            ...
# 234  IOT                British Indian Ocean Territory         Africa
# 235  SGS  South Georgia and the South Sandwich Islands     Antarctica
# 236  HMD             Heard Island and McDonald Islands     Antarctica
# 237  ATF                   French Southern territories     Antarctica
# 238  UMI          United States Minor Outlying Islands        Oceania
#
#                         region  surfacearea  indepyear  population  \
# ...

# %%
inspector = inspect(engine)

tables = inspector.get_table_names()

for table in tables:
    print(table)
# Out:
# city
# country
# countrylanguage

# %%
table_name = 'city'

df_table_city = pd.read_sql_table(table_name, con=engine)
df_table_city
# Out:
#         id            name countrycode       district  population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
table_name = 'countrylanguage'

df_table_cclanguange = pd.read_sql_table(table_name, con=engine)
df_table_cclanguange
# Out:
#     countrycode          language  isofficial  percentage
# 0           AFG            Pashto        True        52.4
# 1           NLD             Dutch        True        95.6
# 2           ANT        Papiamento        True        86.2
# 3           ALB         Albaniana        True        97.9
# 4           DZA            Arabic        True        86.0
# ..          ...               ...         ...         ...
# 979         IND             Asami       False         1.5
# 980         CAN  Eskimo Languages       False         0.1
# 981         CHN              Dong       False         0.2
# 982         RUS       Belorussian       False         0.3
# 983         USA        Portuguese       False         0.2
#
# [984 rows x 4 columns]

# %%
df_table_cclanguange['countrycode']
df_table_cclanguange[df_table_cclanguange['percentage'] > 50]
# Out:
#     countrycode    language  isofficial  percentage
# 0           AFG      Pashto        True        52.4
# 1           NLD       Dutch        True        95.6
# 2           ANT  Papiamento        True        86.2
# 3           ALB   Albaniana        True        97.9
# 4           DZA      Arabic        True        86.0
# ..          ...         ...         ...         ...
# 227         EST    Estonian        True        65.3
# 228         USA     English        True        86.2
# 229         VIR     English        True        81.7
# 231         ZWE       Shona       False        72.1
# 232         PSE      Arabic       False        95.9
#
# [168 rows x 4 columns]

# %%
df_table_cclanguange.groupby('language')[['percentage']].mean()
# Out:
#               percentage
# language
# Abhyasi         1.700000
# Acholi          4.400000
# Adja           11.100000
# Afar           19.550000
# Afrikaans      11.900000
# ...                  ...
# Zapotec         0.600000
# Zenaga          1.200000
# Zhuang          1.400000
# Zulu           13.233333
# [South]Mande    7.700000
#
# [457 rows x 1 columns]

# %%
df_table_cclanguange.value_counts()
# Out:
# countrycode  language    isofficial  percentage
# ABW          Dutch       True        5.3           1
#              English     False       9.5           1
#              Papiamento  False       76.7          1
#              Spanish     False       7.4           1
# AFG          Balochi     False       0.9           1
#                                                   ..
# ZMB          Tongan      False       11.0          1
# ZWE          English     True        2.2           1
#              Ndebele     False       16.2          1
#              Nyanja      False       2.2           1
#              Shona       False       72.1          1
# Name: count, Length: 984, dtype: int64

# %%
df_table_cclanguange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   countrycode  984 non-null    object
#  1   language     984 non-null    object
#  2   isofficial   984 non-null    bool
#  3   percentage   984 non-null    float64
# dtypes: bool(1), float64(1), object(2)
# memory usage: 24.2+ KB

# %%
df_table_cclanguange.sort_values(by='percentage').head(100)
# Out:
#     countrycode          language  isofficial  percentage
# 35          CYM           English        True         0.0
# 30          VGB           English        True         0.0
# 372         OMN           Balochi       False         0.0
# 579         TUV           English        True         0.0
# 383         QAT              Urdu       False         0.0
# ..          ...               ...         ...         ...
# 626         HND           Miskito       False         0.2
# 718         BRA  Indian Languages       False         0.2
# 917         AUT          Romanian       False         0.2
# 703         HUN    Serbo-Croatian       False         0.2
# 882         ITA           Slovene       False         0.2
#
# [100 rows x 4 columns]

# %%
df_table_cclanguange['is']

# %%
df_table_cclanguange.describe()
# Out:
#        percentage
# count  984.000000
# mean    20.374390
# std     30.829452
# min      0.000000
# 25%      1.275000
# 50%      5.300000
# 75%     21.125000
# max    100.000000

# %% [markdown]
# ### 13_Dec

# %%
csv_path_str = r'C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\world_population.csv'

from pathlib import Path
import pandas as pd

csv_path = Path(csv_path_str)
df = pd.read_csv(csv_path)
df.head(5)
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
df.values
# Out:
# array([[36, 'AFG', 'Afghanistan', ..., 63.0587, 1.0257, 0.52],
#        [138, 'ALB', 'Albania', ..., 98.8702, 0.9957, 0.04],
#        [34, 'DZA', 'Algeria', ..., 18.8531, 1.0164, 0.56],
#        ...,
#        [46, 'YEM', 'Yemen', ..., 63.8232, 1.0217, 0.42],
#        [63, 'ZMB', 'Zambia', ..., 26.5976, 1.028, 0.25],
#        [74, 'ZWE', 'Zimbabwe', ..., 41.7665, 1.0204, 0.2]],
#       shape=(234, 17), dtype=object)

# %%
#df['Rank']
#df.Rank
#df.loc[:, 'Rank']
df.iloc[:, 0]
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
df.loc[:, 'Country': '2022 Population']
df.iloc[:, 2: 6]
# Out:
#                Country           Capital Continent  2022 Population
# 0          Afghanistan             Kabul      Asia       41128771.0
# 1              Albania            Tirana    Europe        2842321.0
# 2              Algeria           Algiers    Africa       44903225.0
# 3       American Samoa         Pago Pago   Oceania          44273.0
# 4              Andorra  Andorra la Vella    Europe          79824.0
# ..                 ...               ...       ...              ...
# 229  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# 230     Western Sahara          El Aaiún    Africa         575986.0
# 231              Yemen             Sanaa      Asia       33696614.0
# 232             Zambia            Lusaka    Africa       20017675.0
# 233           Zimbabwe            Harare    Africa       16320537.0
#
# [234 rows x 4 columns]

# %%
df2 = df.set_index('CCA3')
df2.head()
# Out:
#       Rank         Country           Capital Continent  2022 Population  \
# CCA3
# AFG     36     Afghanistan             Kabul      Asia       41128771.0
# ALB    138         Albania            Tirana    Europe        2842321.0
# DZA     34         Algeria           Algiers    Africa       44903225.0
# ASM    213  American Samoa         Pago Pago   Oceania          44273.0
# AND    203         Andorra  Andorra la Vella    Europe          79824.0
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# CCA3
# AFG        38972230.0       33753499.0       28189672.0       19542982.0
# ALB         2866849.0        2882481.0        2913399.0        3182021.0
# DZA        43451666.0       39543154.0       35856344.0       30774621.0
# ASM           46189.0          51368.0          54849.0          58230.0
# AND           77700.0          71746.0          71519.0          66097.0
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# CCA3
# ...

# %%
#df2.iloc[0]
#df2.loc['AFG']

#df2.iloc[0, str(df2).index('AZE')] ???????????????????????????????
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4
#       1 #df2.iloc[0]
#       2 #df2.loc['AFG']
# ----> 4 df2.iloc[0, str(df2).index('AZE')]
#
# ValueError: substring not found

# %%
s_2025 = df2.loc[:, '2022 Population'] * 1.2
s_2025
# Out:
# CCA3
# AFG    49354525.2
# ALB     3410785.2
# DZA    53883870.0
# ASM       53127.6
# AND       95788.8
#           ...
# WLF       13886.4
# ESH      691183.2
# YEM    40435936.8
# ZMB    24021210.0
# ZWE    19584644.4
# Name: 2022 Population, Length: 234, dtype: float64

# %%
df2['2025 Population'] = s_2025
df2
# Out:
#       Rank            Country           Capital Continent  2022 Population  \
# CCA3
# AFG     36        Afghanistan             Kabul      Asia       41128771.0
# ALB    138            Albania            Tirana    Europe        2842321.0
# DZA     34            Algeria           Algiers    Africa       44903225.0
# ASM    213     American Samoa         Pago Pago   Oceania          44273.0
# AND    203            Andorra  Andorra la Vella    Europe          79824.0
# ...    ...                ...               ...       ...              ...
# WLF    226  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# ESH    172     Western Sahara          El Aaiún    Africa         575986.0
# YEM     46              Yemen             Sanaa      Asia       33696614.0
# ZMB     63             Zambia            Lusaka    Africa       20017675.0
# ZWE     74           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
growth_rate_2025 = df2['Growth Rate'] * 0.8
growth_rate_2025
# Out:
# CCA3
# AFG    0.656448
# ALB    0.637248
# DZA    0.650496
# ASM    0.629184
# AND    0.646400
#          ...
# WLF    0.636992
# ESH    0.651776
# YEM    0.653888
# ZMB    0.657920
# ZWE    0.653056
# Name: Growth Rate, Length: 234, dtype: float64

# %%
df2['Growth Rate 2025'] = growth_rate_2025
df2
# Out:
#       Rank            Country           Capital Continent  2022 Population  \
# CCA3
# AFG     36        Afghanistan             Kabul      Asia       41128771.0
# ALB    138            Albania            Tirana    Europe        2842321.0
# DZA     34            Algeria           Algiers    Africa       44903225.0
# ASM    213     American Samoa         Pago Pago   Oceania          44273.0
# AND    203            Andorra  Andorra la Vella    Europe          79824.0
# ...    ...                ...               ...       ...              ...
# WLF    226  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# ESH    172     Western Sahara          El Aaiún    Africa         575986.0
# YEM     46              Yemen             Sanaa      Asia       33696614.0
# ZMB     63             Zambia            Lusaka    Africa       20017675.0
# ZWE     74           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
df2.sort_index(axis=1, ascending=False).head()
# Out:
#       World Population Percentage  Rank  Growth Rate 2025  Growth Rate  \
# CCA3
# AFG                          0.52    36          0.656448      0.82056
# ALB                          0.04   138          0.637248      0.79656
# DZA                          0.56    34          0.650496      0.81312
# ASM                          0.00   213          0.629184      0.78648
# AND                          0.00   203          0.646400      0.80800
#
#       Density (per km²)         Country Continent           Capital  \
# CCA3
# AFG             63.0587     Afghanistan      Asia             Kabul
# ALB             98.8702         Albania    Europe            Tirana
# DZA             18.8531         Algeria    Africa           Algiers
# ASM            222.4774  American Samoa   Oceania         Pago Pago
# AND            170.5641         Andorra    Europe  Andorra la Vella
#
#       Area (km²)  2025 Population  2022 Population  2020 Population  \
# CCA3
# ...

# %%
m1 = df2.loc[:, '2022 Population'] > 50e6
m2 = df2.loc[:, 'Continent'] == 'Asia'
df2.loc[m1&m2, :]
# Out:
#       Rank      Country      Capital Continent  2022 Population  \
# CCA3
# BGD      8   Bangladesh        Dhaka      Asia     1.711864e+08
# CHN      1        China      Beijing      Asia     1.425887e+09
# IND      2        India    New Delhi      Asia     1.417173e+09
# IDN      4    Indonesia      Jakarta      Asia     2.755013e+08
# IRN     17         Iran       Tehran      Asia     8.855057e+07
# JPN     11        Japan        Tokyo      Asia     1.239517e+08
# MMR     26      Myanmar  Nay Pyi Taw      Asia     5.417931e+07
# PAK      5     Pakistan    Islamabad      Asia     2.358249e+08
# PHL     13  Philippines       Manila      Asia     1.155590e+08
# KOR     29  South Korea        Seoul      Asia     5.181581e+07
# THA     20     Thailand      Bangkok      Asia     7.169703e+07
# TUR     18       Turkey       Ankara      Asia     8.534124e+07
# VNM     16      Vietnam        Hanoi      Asia     9.818686e+07
#
# ...

# %%
df3 = df2.select_dtypes(include='float64')
m2d = df3 > 50e6
df3[m2d].dropna(how='all')
# Out:
#       2022 Population  2020 Population  2015 Population  2010 Population  \
# CCA3
# BGD      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# BRA      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# CHN      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# COL      5.187402e+07     5.093066e+07              NaN              NaN
# COD      9.901021e+07     9.285316e+07     7.865690e+07     6.639126e+07
# EGY      1.109901e+08     1.074651e+08     9.772380e+07     8.725241e+07
# ETH      1.233799e+08     1.171909e+08     1.024719e+08     8.923779e+07
# FRA      6.462663e+07     6.448005e+07     6.380977e+07     6.244457e+07
# DEU      8.336984e+07     8.332899e+07     8.207323e+07     8.132509e+07
# IND      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# IDN      2.755013e+08     2.718580e+08     2.590920e+08     2.440162e+08
# IRN      8.855057e+07     8.729019e+07     8.179084e+07     7.537386e+07
# ...
