# %%
import pandas as pd
import numpy as np
from pathlib import Path
path_str = r"C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\world_population.csv"
csv_path = Path(path_str)
df = pd.read_csv(csv_path)
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df2 = df.set_index('CCA3')
df2
# Out:
#       Rank            Country           Capital Continent  2022 Population  \
# CCA3
# AFG     36        Afghanistan             Kabul      Asia       41128771.0
# ALB    138            Albania            Tirana    Europe        2842321.0
# DZA     34            Algeria           Algiers    Africa       44903225.0
# ASM    213     American Samoa         Pago Pago   Oceania          44273.0
# AND    203            Andorra  Andorra la Vella    Europe          79824.0
# ...    ...                ...               ...       ...              ...
# WLF    226  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# ESH    172     Western Sahara          El Aaiún    Africa         575986.0
# YEM     46              Yemen             Sanaa      Asia       33696614.0
# ZMB     63             Zambia            Lusaka    Africa       20017675.0
# ZWE     74           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
df2.head(3)
# Out:
#       Rank      Country  Capital Continent  2022 Population  2020 Population  \
# CCA3
# AFG     36  Afghanistan    Kabul      Asia       41128771.0       38972230.0
# ALB    138      Albania   Tirana    Europe        2842321.0        2866849.0
# DZA     34      Algeria  Algiers    Africa       44903225.0       43451666.0
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# CCA3
# AFG        33753499.0       28189672.0       19542982.0       10694796.0
# ALB         2882481.0        2913399.0        3182021.0        3295066.0
# DZA        39543154.0       35856344.0       30774621.0       25518074.0
#
#       1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# CCA3
# AFG        12486631.0       10752971.0    652230.0            63.0587
# ALB         2941651.0        2324731.0     28748.0            98.8702
# DZA        18739378.0       13795915.0   2381741.0            18.8531
#
#       Growth Rate  World Population Percentage
# CCA3
# ...

# %%
df_pop = df2.loc['AFG': 'AZE', ['Country', '2022 Population']]
df_area = df2.iloc[10:20, [1, -4]]
df_area
# Out:
#          Country  Area (km²)
# CCA3
# ABW        Aruba       180.0
# AUS    Australia   7692024.0
# AUT      Austria     83871.0
# AZE   Azerbaijan     86600.0
# BHS      Bahamas     13943.0
# BHR      Bahrain       765.0
# BGD   Bangladesh    147570.0
# BRB     Barbados       430.0
# BLR      Belarus    207600.0
# BEL      Belgium     30528.0

# %%
adamlar = ['shahriyar', 'nijat', 'murad', 'asgar', 'aynur']
yemekler = ['dolma', 'katlet', 'ash', 'lule', 'bughlama']
rengler = ['cyan', 'qara', 'yashil', 'sari', 'goy']

s_yemek = pd.Series(yemekler, index=adamlar, name='Food')
s_reng = pd.Series(rengler, index=adamlar, name='Color')

# %%
pd.concat([s_yemek, s_reng], ignore_index=False, axis=1)
# Out:
#                Food   Color
# shahriyar     dolma    cyan
# nijat        katlet    qara
# murad           ash  yashil
# asgar          lule    sari
# aynur      bughlama     goy

# %%
pd.concat(
    [df_pop, df_area],
    axis=1
).head(3)
# Out:
#           Country  2022 Population Country  Area (km²)
# CCA3
# AFG   Afghanistan       41128771.0     NaN         NaN
# ALB       Albania        2842321.0     NaN         NaN
# DZA       Algeria       44903225.0     NaN         NaN

# %%
yemekler = ['dolma', 'katlet', 'ash', 'lule', 'xengel']
adamlar_y = ['shahriyar', 'nijat', 'murad', 'asgar', 'isa']

rengler = ['cyan', 'qara', 'yashil', 'sari']
adamlar_r = ['shahriyar', 'nijat', 'murad', 'aynur']

s_yemek = pd.Series(yemekler, index=adamlar_y, name='yemek')
s_reng = pd.Series(rengler, index=adamlar_r, name='reng')

# %%
pd.merge(left=s_yemek, right=s_reng, how='left', left_index=True, right_index=True)
# Out:
#             yemek    reng
# shahriyar   dolma    cyan
# nijat      katlet    qara
# murad         ash  yashil
# asgar        lule     NaN
# isa        xengel     NaN

# %%
pd.merge(left=s_yemek, right=s_reng, how='outer', left_index=True, right_index=True)
# Out:
#             yemek    reng
# asgar        lule     NaN
# aynur         NaN    sari
# isa        xengel     NaN
# murad         ash  yashil
# nijat      katlet    qara
# shahriyar   dolma    cyan

# %%
pd.merge(left=s_yemek, right=s_reng, left_index=True, right_index=True)
# Out:
#             yemek    reng
# shahriyar   dolma    cyan
# nijat      katlet    qara
# murad         ash  yashil

# %%
df_area.head(3)
# Out:
#         Country  Area (km²)
# CCA3
# ABW       Aruba       180.0
# AUS   Australia   7692024.0
# AUT     Austria     83871.0

# %%
df_pop.head(3)
# Out:
#           Country  2022 Population
# CCA3
# AFG   Afghanistan       41128771.0
# ALB       Albania        2842321.0
# DZA       Algeria       44903225.0

# %%
pd.merge(df_pop, df_area.drop('Country', axis=1), how='inner', left_index=True, right_index=True, suffixes=['_pop', '_area'])
# Out:
#          Country  2022 Population  Area (km²)
# CCA3
# ABW        Aruba         106445.0       180.0
# AUS    Australia       26177413.0   7692024.0
# AUT      Austria        8939617.0     83871.0
# AZE   Azerbaijan       10358074.0     86600.0

# %%
pd.merge(df_pop, df_area, how='inner', on='Country')
# Out:
#       Country  2022 Population  Area (km²)
# 0       Aruba         106445.0       180.0
# 1   Australia       26177413.0   7692024.0
# 2     Austria        8939617.0     83871.0
# 3  Azerbaijan       10358074.0     86600.0

# %%
rng = np.random.RandomState(0)  ### ring and seed inside of it 
df = pd.DataFrame({
    'key': ['A', 'B', 'C', 'A', 'B', 'C'],
    'data1': range(6),
    'data2': rng.randint(0, 10, 6)},
    columns = ['key', 'data1', 'data2'])
print(df)
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
rng = np.random.RandomState(0)
data2 = rng.randint(0, 10, 6)
data1 = np.arange(6)

df = pd.DataFrame(
    {
        's': ['A', 'B', 'C'] * 2,
        'data1': data1,
        'data2': data2,
    }
)

# %%
df.groupby(by='s')['data1']

# %%
df.groupby(by='s')['data1'].agg(['mean', 'sum', 'count'])
# Out:
#    mean  sum  count
# s
# A   1.5    3      2
# B   2.5    5      2
# C   3.5    7      2

# %%
df2.groupby('Continent')['2022 Population'].mean()
# Out:
# Continent
# Africa           2.545588e+07
# Asia             9.632739e+07
# Europe           1.505537e+07
# North America    1.500740e+07
# Oceania          2.046386e+06
# South America    3.120119e+07
# Name: 2022 Population, dtype: float64

# %%
df2.groupby('Continent')['2022 Population'].agg(['mean', 'sum', 'count', 'min'])
# Out:
#                        mean           sum  count       min
# Continent
# Africa         2.545588e+07  1.425529e+09     56  107118.0
# Asia           9.632739e+07  4.720042e+09     49  449002.0
# Europe         1.505537e+07  7.377132e+08     49     510.0
# North America  1.500740e+07  6.002961e+08     40    4390.0
# Oceania        2.046386e+06  4.502050e+07     22    1871.0
# South America  3.120119e+07  4.368166e+08     14    3780.0

# %%
df3 = df2.loc[:, 'Continent':]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, AFG to ZWE
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Continent                    234 non-null    object
#  1   2022 Population              230 non-null    float64
#  2   2020 Population              233 non-null    float64
#  3   2015 Population              230 non-null    float64
#  4   2010 Population              227 non-null    float64
#  5   2000 Population              227 non-null    float64
#  6   1990 Population              229 non-null    float64
#  7   1980 Population              229 non-null    float64
#  8   1970 Population              230 non-null    float64
#  9   Area (km²)                   232 non-null    float64
#  10  Density (per km²)            230 non-null    float64
#  11  Growth Rate                  232 non-null    float64
# ...

# %%
df3.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     2.300000e+02     2.330000e+02     2.300000e+02     2.270000e+02
# mean      3.463225e+07     3.360071e+07     3.206600e+07     3.027016e+07
# std       1.378892e+08     1.358732e+08     1.315071e+08     1.260742e+08
# min       5.100000e+02     5.200000e+02     5.640000e+02     5.960000e+02
# 25%       4.197385e+05     4.064710e+05     3.942950e+05     3.827265e+05
# 50%       5.762857e+06     5.456681e+06     5.244415e+06     4.889741e+06
# 75%       2.265372e+07     2.152263e+07     1.973085e+07     1.682585e+07
# max       1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     2.270000e+02     2.290000e+02     2.290000e+02     2.300000e+02
# mean      2.684050e+07     1.933046e+07     1.628288e+07     1.586650e+07
# std       1.133525e+08     8.130962e+07     6.934547e+07     6.835586e+07
# ...

# %%
df3.groupby('Continent')['2022 Population'].mean()
# Out:
# Continent
# Africa           2.545588e+07
# Asia             9.632739e+07
# Europe           1.505537e+07
# North America    1.500740e+07
# Oceania          2.046386e+06
# South America    3.120119e+07
# Name: 2022 Population, dtype: float64

# %%
df3.groupby('Continent').mean()
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa            2.545588e+07     2.387144e+07     2.141970e+07
# Asia              9.632739e+07     9.495513e+07     8.916500e+07
# Europe            1.505537e+07     1.491584e+07     1.502745e+07
# North America     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania           2.046386e+06     1.910149e+06     1.756664e+06
# South America     3.120119e+07     3.082357e+07     2.950960e+07
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
# South America     2.678940e+07     2.501589e+07     2.122474e+07
#
# ...

# %%
df3.groupby('Continent').agg({
   '2022 Population':'mean'
})
# Out:
#                2022 Population
# Continent
# Africa            2.545588e+07
# Asia              9.632739e+07
# Europe            1.505537e+07
# North America     1.500740e+07
# Oceania           2.046386e+06
# South America     3.120119e+07

# %%
df3.groupby('Continent').agg(
    pop_2022 = {'2022 Population':'mean'}
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df3.groupby('Continent').agg(
#       2     pop_2022 = {'2022 Population':'mean'}
#       3 )
#
# File c:\Users\konta\anaconda3\envs\ds\Lib\site-packages\pandas\core\groupby\generic.py:1422, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1420 @doc(_agg_template_frame, examples=_agg_examples_doc, klass="DataFrame")
#    1421 def aggregate(self, func=None, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1422     relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    1423     func = maybe_mangle_lambdas(func)
#    1425     if maybe_use_numba(engine):
#    1426         # Not all agg functions support numba, only propagate numba kwargs
#    1427         # if user asks for numba
#
# ...

# %%
### 18 december

df1 = pd.DataFrame({
    'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
    'group': ['Accounting', 'Engineering','Engineering', 'HR']})
df2 = pd.DataFrame({
    'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
    'hire_date': [2004, 2008, 2012, 2014]})

df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
df2
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014

# %%
df3 = pd.merge(df1, df2, on='employee')
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
from pathlib import Path

car_path = Path(r"C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\car-sales-extended.csv")
births_path = Path(r"C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\births.csv")


birth = pd.read_csv(births_path)
cars = pd.read_csv(car_path)
birth
# Out:
#        year  month  day gender  births
# 0      1969      1  1.0      F    4046
# 1      1969      1  1.0      M    4440
# 2      1969      1  2.0      F    4454
# 3      1969      1  2.0      M    4548
# 4      1969      1  3.0      F    4548
# ...     ...    ...  ...    ...     ...
# 15542  2008     10  NaN      M  183219
# 15543  2008     11  NaN      F  158939
# 15544  2008     11  NaN      M  165468
# 15545  2008     12  NaN      F  173215
# 15546  2008     12  NaN      M  181235
#
# [15547 rows x 5 columns]

# %%
cars
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
df = pd.DataFrame({
    'key': ['A', 'B', 'C', 'A', 'B', 'C'],
    'data': range(6)
    })

df.groupby('key').agg({
    'data': 'mean'
})
# Out:
#      data
# key
# A     1.5
# B     2.5
# C     3.5

# %%
birth.groupby('year')['births'].mean()
# Out:
# year
# 1969      4687.768229
# 1970      4866.927083
# 1971      4664.329843
# 1972      4269.588235
# 1973      4128.772966
# 1974      4139.204961
# 1975      4133.100917
# 1976      4174.081472
# 1977      4378.658344
# 1978      4386.727989
# 1979      4685.133869
# 1980      4843.348059
# 1981      4879.885906
# 1982      4927.081551
# 1983      4863.579439
# 1984      4917.761714
# 1985      5108.635007
# 1986      5109.639946
# 1987      5202.204638
# 1988      5296.066306
# 1989    168570.541667
# 1990    173454.875000
# 1991    171472.583333
# 1992    169559.500000
# 1993    166855.125000
# 1994    164871.875000
# 1995    162625.500000
# 1996    162286.416667
# 1997    161847.041667
# 1998    164383.000000
# 1999    165144.375000
# 2000    169325.958333
# 2001    167980.458333
# 2002    167807.333333
# 2003    170670.500000
# 2004    171621.125000
# 2005    172734.125000
# 2006    178051.041667
# 2007    180167.000000
# 2008    177298.166667
# Name: births, dtype: float64

# %%
birth.groupby(['year', 'month', 'day'])['births'].sum()
# Out:
# year  month  day
# 1969  1      1.0      8486
#              2.0      9002
#              3.0      9542
#              4.0      8960
#              5.0      8390
#                      ...
# 1988  12     27.0    11528
#              28.0    11847
#              29.0    11704
#              30.0    11837
#              31.0     9133
# Name: births, Length: 7567, dtype: int64

# %%
birth.groupby(['year', 'month'])['births'].sum().mean()
# Out:
# np.float64(316196.62083333335)

# %%
birth.groupby('year').agg({'births':'sum'})
# Out:
#        births
# year
# 1969  3600206
# 1970  3737800
# 1971  3563548
# 1972  3266235
# 1973  3146125
# 1974  3170631
# 1975  3153556
# 1976  3176476
# 1977  3332159
# 1978  3338300
# 1979  3499795
# 1980  3617981
# 1981  3635515
# 1982  3685457
# 1983  3642821
# 1984  3673568
# 1985  3765064
# 1986  3760695
# 1987  3813216
# 1988  3913793
# 1989  4045693
# 1990  4162917
# 1991  4115342
# 1992  4069428
# 1993  4004523
# 1994  3956925
# 1995  3903012
# 1996  3894874
# 1997  3884329
# 1998  3945192
# 1999  3963465
# 2000  4063823
# 2001  4031531
# 2002  4027376
# 2003  4096092
# 2004  4118907
# 2005  4145619
# 2006  4273225
# 2007  4324008
# 2008  4255156

# %%
birth.groupby(['year', 'month']).agg(
    {
        'births': 'sum'
    }
).mean()
# Out:
# births    316196.620833
# dtype: float64

# %%
birth.groupby('gender')['births'].sum()
# Out:
# gender
# F    74035823
# M    77738555
# Name: births, dtype: int64

# %%
birth.groupby('gender')['births'].mean()
# Out:
# gender
# F     9521.067773
# M    10003.674559
# Name: births, dtype: float64

# %%
rng = np.random.RandomState(0)
df = pd.DataFrame({
    'key': ['A', 'B', 'C', 'A', 'B', 'C'],
    'data1': range(6),
    'data2': rng.randint(0, 10, 6)
    })
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
# df.groupby('key')['data1'].sum()

df.groupby('key').agg(
    {
        'data1': 'sum'
    }
)
# Out:
#      data1
# key
# A        3
# B        5
# C        7

# %%
# df.groupby('key')[['data1', 'data2']].sum()


df.groupby('key').agg(
    {
        'data1': ['sum', 'mean'], 'data2':'mean'  #multiindex
    }
)
# Out:
#     data1      data2
#       sum mean  mean
# key
# A       3  1.5   4.0
# B       5  2.5   3.5
# C       7  3.5   6.0

# %%
cars.groupby('Make').agg({
    'Price': ['sum', 'min', 'mean']
})
# Out:
#           Price
#             sum   min          mean
# Make
# BMW     2708983  9362  27089.830000
# Honda   4412317  3509  14514.200658
# Nissan  2704357  2796  13658.368687
# Toyota  6220008  3125  15628.160804

# %%
cars.groupby(['Make', 'Colour']).agg(
    {
        'Price': 'mean'
    }
)
# Out:
#                       Price
# Make   Colour
# BMW    Black   24706.000000
#        Blue    28845.058824
#        Green   19438.750000
#        Red     22510.230769
#        White   29255.675676
# Honda  Black   13926.031250
#        Blue    14107.019231
#        Green   17320.444444
#        Red     15180.615385
#        White   14460.403226
# Nissan Black   13601.000000
#        Blue    14078.483333
#        Green   12509.562500
#        Red     13069.166667
#        White   13710.505618
# Toyota Black   16680.750000
#        Blue    16069.764228
#        Green   13585.783784
#        Red     13848.756757
#        White   15887.872611

# %%
birth.groupby('gender')['births'].mean()
# Out:
# gender
# F     9521.067773
# M    10003.674559
# Name: births, dtype: float64

# %%
gender_avg = birth.groupby('gender')['births'].transform('mean')
birth['gender_avg'] = gender_avg

birth
# Out:
#        year  month  day gender  births    gender_avg
# 0      1969      1  1.0      F    4046   9521.067773
# 1      1969      1  1.0      M    4440  10003.674559
# 2      1969      1  2.0      F    4454   9521.067773
# 3      1969      1  2.0      M    4548  10003.674559
# 4      1969      1  3.0      F    4548   9521.067773
# ...     ...    ...  ...    ...     ...           ...
# 15542  2008     10  NaN      M  183219  10003.674559
# 15543  2008     11  NaN      F  158939   9521.067773
# 15544  2008     11  NaN      M  165468  10003.674559
# 15545  2008     12  NaN      F  173215   9521.067773
# 15546  2008     12  NaN      M  181235  10003.674559
#
# [15547 rows x 6 columns]

# %%
cars.groupby('Make')['Price'].mean().to_frame()
# Out:
#                Price
# Make
# BMW     27089.830000
# Honda   14514.200658
# Nissan  13658.368687
# Toyota  15628.160804

# %%
cars_make_mean = cars.groupby('Make')['Price'].transform('mean')

cars['make_mean'] = cars_make_mean

# %%
cars
# Out:
#        Make Colour  Odometer (KM)  Doors  Price     make_mean
# 0     Honda  White          35431      4  15323  14514.200658
# 1       BMW   Blue         192714      5  19943  27089.830000
# 2     Honda  White          84714      4  28343  14514.200658
# 3    Toyota  White         154365      4  13434  15628.160804
# 4    Nissan   Blue         181577      3  14043  13658.368687
# ..      ...    ...            ...    ...    ...           ...
# 995  Toyota  Black          35820      4  32042  15628.160804
# 996  Nissan  White         155144      3   5716  13658.368687
# 997  Nissan   Blue          66604      4  31570  13658.368687
# 998   Honda  White         215883      4   4001  14514.200658
# 999  Toyota   Blue         248360      4  12732  15628.160804
#
# [1000 rows x 6 columns]

# %%
m = cars['make_mean'] > cars['Price']

# %%
cars[m]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price     make_mean
# 1       BMW   Blue         192714      5  19943  27089.830000
# 3    Toyota  White         154365      4  13434  15628.160804
# 6    Toyota   Blue         163453      4   8473  15628.160804
# 8    Nissan  White         130538      4   9374  13658.368687
# 11   Nissan  Green          17119      4   6160  13658.368687
# ..      ...    ...            ...    ...    ...           ...
# 991   Honda   Blue         235985      4   9184  14514.200658
# 993  Nissan  Black         162523      4   4696  13658.368687
# 996  Nissan  White         155144      3   5716  13658.368687
# 998   Honda  White         215883      4   4001  14514.200658
# 999  Toyota   Blue         248360      4  12732  15628.160804
#
# [567 rows x 6 columns]

# %%
mask = cars['Price'] - cars['make_mean'] < 0

cars[mask]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price     make_mean
# 1       BMW   Blue         192714      5  19943  27089.830000
# 3    Toyota  White         154365      4  13434  15628.160804
# 6    Toyota   Blue         163453      4   8473  15628.160804
# 8    Nissan  White         130538      4   9374  13658.368687
# 11   Nissan  Green          17119      4   6160  13658.368687
# ..      ...    ...            ...    ...    ...           ...
# 991   Honda   Blue         235985      4   9184  14514.200658
# 993  Nissan  Black         162523      4   4696  13658.368687
# 996  Nissan  White         155144      3   5716  13658.368687
# 998   Honda  White         215883      4   4001  14514.200658
# 999  Toyota   Blue         248360      4  12732  15628.160804
#
# [567 rows x 6 columns]

# %%
# cars.groupby('Make')['Price'].mean()
def less_than_avg(small_df):
    return small_df['Price'].std() < small_df['Price'].mean()

cars.groupby('Make').filter(less_than_avg)
# Out:
# 8630.79421870436

# %% [markdown]
# ### 20 december_continue

# %%
import pathlib
import pandas as pd

csv_path = pathlib.Path(r"C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\1.04. Real-life example.csv")
df = pd.read_csv(csv_path)
df
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
df_yeni = df.copy()
df_yeni.set_index('Brand', inplace=True)

yeni_cols = [
['General', 'General', 'General', 'General', 'Main', 'Main', 'Main', 'Main'],
['Price', 'Body', 'Mileage', 'EngineV', 'Engine Type', 'Registration', 'Year', 'Model']
]

df_yeni.columns = yeni_cols
df_yeni.head(3)
# Out:
#                General                               Main                     \
#                  Price   Body Mileage EngineV Engine Type Registration  Year
# Brand
# BMW             4200.0  sedan     277     2.0      Petrol          yes  1991
# Mercedes-Benz   7900.0    van     427     2.9      Diesel          yes  1999
# Mercedes-Benz  13300.0  sedan     358     5.0         Gas          yes  2003
#
#
#                       Model
# Brand
# BMW                     320
# Mercedes-Benz  Sprinter 212
# Mercedes-Benz         S 500

# %%
mask = df_yeni.loc[:, ('General', 'Body')] != 'sedan'
df_yeni.loc[mask]
# Out:
#                 General                                   Main               \
#                   Price       Body Mileage EngineV Engine Type Registration
# Brand
# Mercedes-Benz    7900.0        van     427     2.9      Diesel          yes
# Audi            23000.0  crossover     240     4.2      Petrol          yes
# Toyota          18300.0  crossover     120     2.0      Petrol          yes
# Mercedes-Benz  199999.0  crossover       0     5.5      Petrol          yes
# Audi            14200.0      vagon     200     2.7      Diesel          yes
# ...                 ...        ...     ...     ...         ...          ...
# Renault          7000.0        van     210     1.5      Diesel          yes
# BMW             12090.0      hatch     145     1.6      Petrol          yes
# Renault          2100.0      vagon     237     1.9      Diesel           no
# Volkswagen      11500.0        van     163     2.5      Diesel          yes
# ...

# %%
mask = (df['Body'] == 'crossover') | (df['Body'] == 'hatch')

df[mask].groupby(['Brand', 'Body']).agg({
    'Price': 'sum',
    'Mileage': 'mean',
    'Model': 'nunique'
})
# Out:
#                               Price     Mileage  Model
# Brand         Body
# Audi          crossover  2856303.25   98.753247      5
#               hatch       367214.00  123.157895      6
# BMW           crossover  7342248.00  103.125654      7
#               hatch       226112.00  109.750000      7
# Mercedes-Benz crossover  9490101.00   90.148810     31
#               hatch       336956.00  126.391304     11
# Mitsubishi    crossover  2165697.85  121.875912      7
#               hatch        90435.25  204.473684      5
# Renault       crossover   263093.41   72.263158      6
#               hatch       302317.15  124.658537     10
# Toyota        crossover  7202984.94  114.273543     17
#               hatch       586874.39   96.101695      7
# Volkswagen    crossover  2514893.55  109.779070      6
#               hatch       904019.78  153.723214     16

# %%
df.groupby('Brand')['Price'].mean()
df2 = df.groupby('Brand', as_index=False).agg({
    'Price' : 'mean'
})
df3 = df.drop('brand_avg', axis='columns')
pd.merge(df3, df2, how='left', on='Brand')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 df.groupby('Brand')['Price'].mean()
#       2 df2 = df.groupby('Brand', as_index=False).agg({
#       3     'Price' : 'mean'
#       4 })
# ----> 5 pd.merge(df3, df2, how='left', on='Brand')
#
# NameError: name 'df3' is not defined

# %%
# df.loc[:, 'EngineV'].unique().sort()
# df
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
df.groupby('Model')['EngineV'].min().head(3)
# Out:
# Model
# 1 Series    1.6
# 100         2.0
# 11          1.4
# Name: EngineV, dtype: float64

# %%
df.groupby('Model').filter(lambda small_df:small_df['EngineV'].min() > 2)
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 5     Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 12             Audi    9500.0      vagon      165      2.7         Gas
# ...             ...       ...        ...      ...      ...         ...
# 4327           Audi   80999.0  crossover        0      3.0      Diesel
# 4330            BMW   21335.0      other      105      3.0      Petrol
# 4331            BMW   45000.0  crossover       80      3.0      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
#
#      Registration  Year         Model
# 1             yes  1999  Sprinter 212
# ...

# %%
df_excel = df.groupby(['Brand', 'Body']).agg({
    'Price':'mean'
})

# %%
df.groupby(['Brand', 'Body']).agg({
    'Price':'mean'
}).unstack()
# Out:
#                       Price                                            \
# Body              crossover         hatch         other         sedan
# Brand
# Audi           39127.441781  20400.777778  28293.285714  14171.281100
# BMW            41955.702857  20555.636364  23736.474576  16129.906414
# Mercedes-Benz  66831.697183  14650.260870  33092.544776  23080.077135
# Mitsubishi     16042.206296   4759.750000  11783.507692   7659.484375
# Renault        13847.021579   7373.589024   8645.147059   7156.349655
# Toyota         34137.369384  10296.041930  23919.135135  14078.361768
# Volkswagen     29586.982941   8218.361636  11640.494624  12413.651241
#
#
# Body                  vagon           van
# Brand
# Audi            9375.830189   3000.000000
# BMW            14477.023810           NaN
# Mercedes-Benz  11924.500000  18823.770588
# Mitsubishi      7700.000000   6285.285714
# Renault         8381.641481   7573.402041
# Toyota         15147.937500  21381.250000
# ...

# %%
df.pivot_table(
    values='Price',
    index='Brand',
    columns='Body',
    aggfunc='mean'
)
# Out:
# Body              crossover         hatch         other         sedan  \
# Brand
# Audi           39127.441781  20400.777778  28293.285714  14171.281100
# BMW            41955.702857  20555.636364  23736.474576  16129.906414
# Mercedes-Benz  66831.697183  14650.260870  33092.544776  23080.077135
# Mitsubishi     16042.206296   4759.750000  11783.507692   7659.484375
# Renault        13847.021579   7373.589024   8645.147059   7156.349655
# Toyota         34137.369384  10296.041930  23919.135135  14078.361768
# Volkswagen     29586.982941   8218.361636  11640.494624  12413.651241
#
# Body                  vagon           van
# Brand
# Audi            9375.830189   3000.000000
# BMW            14477.023810           NaN
# Mercedes-Benz  11924.500000  18823.770588
# Mitsubishi      7700.000000   6285.285714
# Renault         8381.641481   7573.402041
# Toyota         15147.937500  21381.250000
# Volkswagen      9583.586596  12359.136846

# %%
df_excel.reset_index().to_excel('Excel_Pivot1.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4345 entries, 0 to 4344
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         4345 non-null   object
#  1   Price         4173 non-null   float64
#  2   Body          4345 non-null   object
#  3   Mileage       4345 non-null   int64
#  4   EngineV       4195 non-null   float64
#  5   Engine Type   4345 non-null   object
#  6   Registration  4345 non-null   object
#  7   Year          4345 non-null   int64
#  8   Model         4345 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 305.6+ KB

# %%
df['Brand'].str.replace('Toy', 'TOY', regex=False)
# Out:
# 0                 BMW
# 1       Mercedes-Benz
# 2       Mercedes-Benz
# 3                Audi
# 4              TOYota
#             ...
# 4340    Mercedes-Benz
# 4341              BMW
# 4342              BMW
# 4343           TOYota
# 4344       Volkswagen
# Name: Brand, Length: 4345, dtype: object

# %%
from datetime import datetime, timedelta

# %%
BD = datetime(year=1887, month=10, day=2)
today = datetime.today()
today
# Out:
# datetime.datetime(2025, 12, 20, 20, 46, 49, 969059)

# %%
td = (today - BD)
# Out:
# 50483

# %%
tdi = pd.Timestamp(today) - pd.Timestamp(BD)

# %%
tdi / 30 / 12
# Out:
# Timedelta('140 days 05:35:27.805469')

# %%
pd.timedelta_range(start='1 day', periods=2, freq='d')
# Out:
# TimedeltaIndex(['1 days', '2 days'], dtype='timedelta64[ns]', freq='D')

# %%
# %pip install yFinance
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      -------------------- ------------------- 1.6/3.0 MB 5.6 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 7.7 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
# ...

# %%
import yfinance as yf
import datetime

tickers = ['NVDA']

start_date = datetime.datetime(2023, 1, 1)
end_date = datetime.datetime.now()
data = yf.download(tickers, start=start_date, end=end_date)
data = data.droplevel(axis=1, level=1)
data
# Out:
# C:\Users\konta\AppData\Local\Temp\ipykernel_9580\2727356413.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Date
# 2023-01-03   14.300684   14.981004   14.081903   14.836148  401277000
# 2023-01-04   14.734250   14.838146   14.226759   14.552433  431324000
# 2023-01-05   14.250735   14.549436   14.133852   14.476509  389168000
# 2023-01-06   14.844140   14.994989   14.019965   14.459525  405044000
# 2023-01-09   15.612371   16.039943   15.125858   15.268716  504231000
# ...                ...         ...         ...         ...        ...
# 2025-12-19  180.990005  181.449997  176.339996  176.669998  324925900
# 2025-12-22  183.690002  184.160004  182.350006  183.919998  129064400
# ...

# %%
data = data['Close']
data

data.groupby?
# Out:
# Signature:
# data.groupby(
#     by=None,
#     axis: 'Axis' = 0,
#     level: 'IndexLabel | None' = None,
#     as_index: 'bool' = True,
#     sort: 'bool' = True,
#     group_keys: 'bool' = True,
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     dropna: 'bool' = True,
# ) -> 'SeriesGroupBy'
# Docstring:
# Group Series using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, pd.Grouper or list of such
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
# ...

# %%
data.loc['2023-01']
# Out:
# Date
# 2023-01-03    14.300684
# 2023-01-04    14.734250
# 2023-01-05    14.250734
# 2023-01-06    14.844139
# 2023-01-09    15.612370
# 2023-01-10    15.893089
# 2023-01-11    15.984997
# 2023-01-12    16.494484
# 2023-01-13    16.882099
# 2023-01-17    17.684299
# 2023-01-18    17.359623
# 2023-01-19    16.748234
# 2023-01-20    17.821161
# 2023-01-23    19.173803
# 2023-01-24    19.245733
# 2023-01-25    19.303675
# 2023-01-26    19.782194
# 2023-01-27    20.344635
# 2023-01-30    19.142836
# 2023-01-31    19.517462
# Name: Close, dtype: float64

# %%
data.loc['2023-12':'2024-12']
# Out:
# Date
# 2023-12-01     46.734852
# 2023-12-04     45.480659
# 2023-12-05     46.540070
# 2023-12-06     45.477661
# 2023-12-07     46.570061
#                  ...
# 2024-12-24    140.181656
# 2024-12-26    139.891739
# 2024-12-27    136.972519
# 2024-12-30    137.452393
# 2024-12-31    134.253281
# Name: Close, Length: 272, dtype: float64

# %%
data.between_time('2023-12', '2024-03')
# Out:
# Date
# 2023-01-03     14.300684
# 2023-01-04     14.734250
# 2023-01-05     14.250734
# 2023-01-06     14.844139
# 2023-01-09     15.612370
#                  ...
# 2025-12-15    176.289993
# 2025-12-16    177.720001
# 2025-12-17    170.940002
# 2025-12-18    174.139999
# 2025-12-19    180.990005
# Name: Close, Length: 745, dtype: float64

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

def combine_two_tables(person: pd.DataFrame, address: pd.DataFrame) -> pd.DataFrame:
    pass
pd.merge?
# Out:
# Signature:
# pd.merge(
#     left: 'DataFrame | Series',
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_on: 'IndexLabel | AnyArrayLike | None' = None,
#     right_on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
# Out:
# Object `pd.groupby` not found.
