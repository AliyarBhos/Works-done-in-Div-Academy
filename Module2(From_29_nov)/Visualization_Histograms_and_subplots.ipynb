# %%
import numpy as np
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng(0)

data = rng.normal(23, 3, 1000)

plt.hist(
    data, 
    histtype='bar', 
    color='steelblue', 
    alpha=0.5, 
    edgecolor='black', 
    bins=5,
    density=True
    )
# Out:
# (array([0.00215348, 0.02967022, 0.11868087, 0.07896106, 0.00981031]),
#  array([11.30173481, 15.48100989, 19.66028497, 23.83956005, 28.01883514,
#         32.19811022]),
#  <BarContainer object of 5 artists>)

# %%
housing_path = Path(r'C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\housing.csv')
df = pd.read_csv(housing_path)

df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.hist(df['median_house_value'], 
         color='orange',
         alpha=0.5,
         edgecolor='k',
         bins=30,
         density=True
         )

plt.title('California Median House Prices')

plt.ylabel('Count')
plt.xlabel('Median Price')
# Out:
# Text(0.5, 0, 'Median Price')

# %%
# %pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\konta\anaconda3\envs\ds\lib\site-packages (from plotly) (25.0)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.9 MB 3.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.9 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.9 MB 3.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.9 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.9 MB 2.4 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.9 MB 2.4 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.9 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.9 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/9.9 MB 1.8 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/9.9 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.9 MB 1.6 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.9 MB 1.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.2/9.9 MB 1.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.2/9.9 MB 1.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.2/9.9 MB 1.4 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.9 MB 1.1 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.9 MB 1.1 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.9 MB 1.1 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.9 MB 1.1 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.9 MB 1.1 MB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.9 MB 1.0 MB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.9 MB 1.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 5.5/9.9 MB 967.0 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.5/9.9 MB 967.0 kB/s eta 0:00:05
#    ----------------------- ---------------- 5.8/9.9 MB 937.0 kB/s eta 0:00:05
#    ----------------------- ---------------- 5.8/9.9 MB 937.0 kB/s eta 0:00:05
#    ------------------------ --------------- 6.0/9.9 MB 920.4 kB/s eta 0:00:05
#    ------------------------ --------------- 6.0/9.9 MB 920.4 kB/s eta 0:00:05
#    ------------------------- -------------- 6.3/9.9 MB 905.8 kB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.9 MB 905.8 kB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.9 MB 888.9 kB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.9 MB 888.9 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 866.5 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 866.5 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 866.5 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 866.5 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.1/9.9 MB 826.1 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.1/9.9 MB 826.1 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.1/9.9 MB 826.1 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.3/9.9 MB 796.1 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.3/9.9 MB 796.1 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.3/9.9 MB 796.1 kB/s eta 0:00:04
#    ------------------------------ --------- 7.6/9.9 MB 767.5 kB/s eta 0:00:03
#    ------------------------------ --------- 7.6/9.9 MB 767.5 kB/s eta 0:00:03
#    ------------------------------- -------- 7.9/9.9 MB 749.6 kB/s eta 0:00:03
#    ------------------------------- -------- 7.9/9.9 MB 749.6 kB/s eta 0:00:03
#    ------------------------------- -------- 7.9/9.9 MB 749.6 kB/s eta 0:00:03
#    -------------------------------- ------- 8.1/9.9 MB 738.0 kB/s eta 0:00:03
#    -------------------------------- ------- 8.1/9.9 MB 738.0 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/9.9 MB 733.6 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/9.9 MB 733.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.7/9.9 MB 732.4 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/9.9 MB 732.4 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 729.4 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 729.4 kB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.9 MB 723.9 kB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 723.9 kB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 722.3 kB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 722.3 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 720.7 kB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 720.1 kB/s  0:00:13
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.14.0 plotly-6.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

px.histogram(df, x='median')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 import plotly.express as px
# ----> 3 px.histogram(df)
#
# File c:\Users\konta\anaconda3\envs\ds\Lib\site-packages\plotly\express\_chart_types.py:490, in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, subtitle, template, width, height)
#     443 def histogram(
#     444     data_frame=None,
#     445     x=None,
#    (...)    482     height=None,
#     483 ) -> go.Figure:
#     484     """
#     485     In a histogram, rows of `data_frame` are grouped together into a
#     486     rectangular mark to visualize the 1D distribution of an aggregate
#     487     function `histfunc` (e.g. the count or sum) of the value `y` (or `x` if
#     488     `orientation` is `'h'`).
#     489     """
# --> 490     return make_figure(
#     491         args=locals(),
#     492         constructor=go.Histogram,
#     493         trace_patch=dict(
#     494             histnorm=histnorm,
#     495             histfunc=histfunc,
#     496             cumulative=dict(enabled=cumulative),
#     497         ),
#     498         layout_patch=dict(barmode=barmode, barnorm=barnorm),
#     499     )
#
# File c:\Users\konta\anaconda3\envs\ds\Lib\site-packages\plotly\express\_core.py:2491, in make_figure(args, constructor, trace_patch, layout_patch)
#    2488 layout_patch = layout_patch or {}
#    2489 apply_default_cascade(args)
# -> 2491 args = build_dataframe(args, constructor)
#    2492 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2493     args = process_dataframe_hierarchy(args)
#
# File c:\Users\konta\anaconda3\envs\ds\Lib\site-packages\plotly\express\_core.py:1789, in build_dataframe(args, constructor)
#    1787         dtype = v_dtype
#    1788     elif dtype != v_dtype:
# -> 1789         raise ValueError(
#    1790             "Plotly Express cannot process wide-form data with columns of different type."
#    1791         )
#    1792 df_output = df_output.unpivot(
#    1793     index=wide_id_vars,
#    1794     on=wide_value_vars,
#    1795     variable_name=var_name,
#    1796     value_name=value_name,
#    1797 )
#    1798 assert len(df_output.columns) == len(set(df_output.columns)), (
#    1799     "Wide-mode name-inference failure, likely due to a internal bug. "
#    1800     "Please report this to "
#    1801     "https://github.com/plotly/plotly.py/issues/new and we will try to "
#    1802     "replicate and fix it."
#    1803 )
#
# ValueError: Plotly Express cannot process wide-form data with columns of different type.

# %%
x = np.linspace(0,10,100)

fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 0.5])
ax1.plot(x, np.sin(x))


ax2 = fig.add_axes([0, 0.5, 1, 0.5])
ax2.plot(x, np.cos(x), color='red')
ax2.set_xticks([])
# Out:
# []

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,1,1)
ax1.plot(x, np.sin(x))
ax2 = fig.add_subplot(2,1,2)
ax2.plot(x, np.cos(x))

# %%
fig, axs = plt.subplots(1, 2)

# %%
fig

# %%
axs
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
axs[0].plot(x, np.sin(x))

# %%
fig, axs = plt.subplots(2,3)

axs[0, 0].plot(x, np.sin(x))
axs[0, 1].plot(x, np.cos(x))
axs[0, 1].plot(x, np.cos(x))

# %%
fig, axs = plt.subplots(2,3)

for i in range(axs.shape[0]):
    for j in range(axs.shape[1]):
        ax = axs[i, j]
        ax.plot(x, np.sin(x-i)+j)
