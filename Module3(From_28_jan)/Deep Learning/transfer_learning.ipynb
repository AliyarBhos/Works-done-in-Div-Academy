# %%
import torchvision.datasets
for _ in torchvision.datasets.__all__: print('\n',_)
# Out:
#  LSUN
#
#  LSUNClass
#
#  ImageFolder
#
#  DatasetFolder
#
#  FakeData
#
#  CocoCaptions
#
#  CocoDetection
#
#  CIFAR10
#
#  CIFAR100
#
#  EMNIST
#
#  FashionMNIST
#
#  QMNIST
#
#  MNIST
#
#  KMNIST
#
#  MovingMNIST
#
#  StanfordCars
#
#  STL10
#
#  SUN397
#
#  SVHN
#
#  PhotoTour
#
#  SEMEION
#
#  Omniglot
#
#  SBU
#
#  Flickr8k
#
#  Flickr30k
#
#  Flowers102
#
#  VOCSegmentation
#
#  VOCDetection
#
#  Cityscapes
#
#  ImageNet
#
#  Caltech101
#
#  Caltech256
#
#  CelebA
#
#  WIDERFace
#
#  SBDataset
#
#  VisionDataset
#
#  USPS
#
#  Kinetics
#
#  HMDB51
#
#  UCF101
#
#  Places365
#
#  Kitti
#
#  INaturalist
#
#  LFWPeople
#
#  LFWPairs
#
#  KittiFlow
#
#  Sintel
#
#  FlyingChairs
#
#  FlyingThings3D
#
#  HD1K
#
#  Food101
#
#  DTD
#
#  FER2013
#
#  GTSRB
#
#  CLEVRClassification
#
#  OxfordIIITPet
#
#  PCAM
#
#  Country211
#
#  FGVCAircraft
#
#  EuroSAT
#
#  RenderedSST2
#
#  Kitti2012Stereo
#
#  Kitti2015Stereo
#
#  CarlaStereo
#
#  Middlebury2014Stereo
#
#  CREStereo
#
# ...
