# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(
    n_samples=200,
    n_features=2,
    centers=5,
    cluster_std=0.5, 
    random_state=10,
)

# %%
X
# Out:
# array([[  2.52497277,   5.40018196],
#        [ -5.72861545,   4.67633039],
#        [ -6.92493569,  -7.81466283],
#        [ -6.50472009,  -8.29114408],
#        [  5.55916866,  -9.53068675],
#        [ -5.53175039,   4.72551533],
#        [ -6.30830881,  -7.99458656],
#        [  2.31942897,   5.24941007],
#        [ -7.46376723,  -7.92497826],
#        [ -6.006583  ,   5.12741156],
#        [ -5.43015193,   5.30193793],
#        [  2.64200868,   4.59913117],
#        [  2.64894404,   4.73568398],
#        [  0.01802186,  -5.27955622],
#        [ -0.80351245,  -4.83166383],
#        [ -6.77938388,  -7.90113091],
#        [ -7.24857814,  -8.34283385],
#        [  2.86184124,   5.78328164],
#        [  2.11141268,   4.78171368],
#        [  6.6237647 ,  -9.12623154],
#        [  2.55446261,   5.00472023],
#        [  5.25684274,  -9.42887604],
#        [ -6.70098362,  -8.0984175 ],
#        [ -6.60487947,  -7.1327205 ],
#        [ -6.05693397,   4.78710612],
#        [  2.64854944,   5.17274826],
#        [  1.08266507,  -5.44547638],
#        [ -6.604735  ,  -8.71805655],
#        [ -6.6736525 ,   5.37230921],
#        [  5.42855858,  -9.67226112],
#        [ -5.66109273,   5.65035709],
#        [ -6.00434197,   5.9166464 ],
#        [ -6.33097028,   5.51162538],
#        [ -5.59585528,   5.34281159],
#        [  5.4134602 ,  -9.44041391],
#        [ -6.0394388 ,  -7.92856258],
#        [  2.90340892,   5.30726466],
#        [  5.31032174,  -9.83582546],
#        [ -5.20170493,   5.79247609],
#        [  5.29078887,  -9.27835892],
#        [ -5.23301406,   5.33028388],
#        [  5.94950429, -10.29423903],
#        [  5.75652864,  -9.76039696],
#        [ -6.58114176,  -7.64633751],
#        [  5.49276701,  -9.82303202],
#        [  0.0446206 ,  -5.34651151],
#        [  3.50132301,   5.31002246],
#        [ -5.87367407,  -8.16308028],
#        [  3.02637993,   4.58244319],
#        [  0.23708265,  -5.13207989],
#        [ -6.40005307,   5.25268402],
#        [ -6.45649696,   5.31583961],
#        [ -0.74030001,  -5.84354048],
#        [ -0.19641034,  -5.89976247],
#        [  5.37027663,  -9.76605124],
#        [ -6.52307335,  -8.21081637],
#        [  6.054649  ,  -9.95094576],
#        [  0.31409261,  -6.27060145],
#        [ -6.15872085,   4.86308592],
#        [  0.22173484,  -4.90689179],
#        [  2.81943506,   4.74067403],
#        [ -0.36587147,  -5.45116105],
#        [  5.47598747,  -8.88596282],
#        [  0.14687905,  -5.60770683],
#        [  5.15647333,  -9.230881  ],
#        [  2.51655032,   4.80163669],
#        [  3.02894421,   5.43521223],
#        [ -0.23272452,  -5.11317949],
#        [ -6.2380476 ,  -8.25016722],
#        [  2.55799138,   4.41130205],
#        [ -5.93507792,   5.13808198],
#        [ -7.43525534,  -8.01573508],
#        [ -0.56970845,  -5.565602  ],
#        [  0.47357082,  -5.65128009],
#        [  2.52914999,   4.29642236],
#        [  2.06004671,   4.86518108],
#        [ -0.38625947,  -5.63449683],
#        [ -6.29095211,  -9.32150803],
#        [  2.73170253,   4.02234921],
#        [ -6.41942027,  -8.52126215],
#        [  0.18823289,  -5.52302603],
#        [ -5.79624139,   4.38131189],
#        [ -0.53221793,  -5.20834055],
#        [ -6.73532438,  -8.86361762],
#        [ -5.68630744,  -9.22502197],
#        [ -0.54223624,  -5.42386751],
#        [ -0.88539535,  -5.19791843],
#        [  3.08646401,   3.99882159],
#        [ -5.54870564,   4.01282824],
#        [  2.43191813,   5.02087146],
#        [  5.64292596,  -8.98344233],
#        [  3.36458081,   5.14919421],
#        [ -4.87917905,   5.36494808],
#        [  3.8751275 ,   4.60639928],
#        [  3.34292785,   4.99073251],
#        [ -6.02362489,  -8.35607641],
#        [ -5.94227471,   5.2126267 ],
#        [  6.16868137, -10.12486346],
#        [ -5.1298514 ,   4.93259057],
#        [  0.08404893,  -5.37947776],
#        [ -6.38659049,  -8.84313148],
#        [ -0.23059616,  -4.83297745],
#        [ -7.10964733,  -8.02693736],
#        [ -5.81956009,   4.81944265],
#        [  2.9283219 ,   5.18322647],
#        [ -6.12078035,   4.63620811],
#        [  4.85811176,  -9.51739257],
#        [ -6.27444275,   5.38535245],
#        [  5.38585177,  -9.84960905],
#        [ -6.01039194,  -7.72906223],
#        [  2.83913967,   5.54356424],
#        [ -6.38185051,   5.48458621],
#        [ -5.98293763,  -7.53453473],
#        [ -5.55988708,   5.61822458],
#        [ -6.1050295 ,   5.06549134],
#        [  5.58378975,  -8.35113548],
#        [  5.99080544,  -9.93386603],
#        [  5.98825849,  -8.74864991],
#        [ -6.50909759,   5.18381699],
#        [  0.10722664,  -5.76152205],
#        [  0.24435428,  -5.20246756],
#        [  5.84752523,  -9.48317061],
#        [  3.1442149 ,   3.48627927],
#        [ -0.31161259,  -5.07665271],
#        [  6.08064941,  -9.48745437],
#        [ -5.67348898,   4.3614135 ],
#        [ -6.4804732 ,   5.78964003],
#        [ -6.43013049,  -8.27516134],
#        [  3.22681882,   5.09834964],
#        [ -6.41198206,  -8.0892985 ],
#        [  5.24516327,  -9.64591386],
#        [  2.80948936,   4.16679228],
#        [  5.7089892 ,  -9.65867114],
#        [  0.17137479,  -5.6904478 ],
#        [  3.28203912,   4.94781729],
#        [ -0.17286076,  -5.93544624],
#        [  5.55944795,  -8.39247735],
#        [ -7.43557658,  -8.11080467],
#        [  0.46343915,  -5.48995341],
#        [  0.03670899,  -4.90269515],
#        [  3.18422275,   5.05948278],
#        [ -0.7510092 ,  -6.30849227],
#        [ -7.37532111,  -8.50256298],
#        [ -6.22044063,  -8.47977409],
#        [  2.21151007,   5.21095337],
#        [ -6.35067079,  -8.2311527 ],
#        [  2.60078132,   4.77600847],
#        [ -0.31731859,  -5.68415266],
#        [  0.55372443,  -5.7900555 ],
#        [  5.29275427,  -9.85961552],
#        [ -6.51914716,  -8.36084394],
#        [ -7.13308738,  -8.9120525 ],
#        [  5.58609108,  -9.35450956],
#        [  4.9038466 ,  -9.98396542],
#        [  3.34523941,   5.22283531],
#        [ -5.4881746 ,   5.39667552],
#        [ -5.49612917,   5.38908378],
#        [  2.45345158,   5.04662973],
#        [  5.31851792,  -9.09042478],
#        [  4.94388003,  -9.07082397],
#        [  5.39348894, -10.65081707],
#        [  4.95669619,  -9.82962962],
#        [  4.49832013,  -9.69634786],
#        [ -6.64056945,   5.31553381],
#        [ -5.78677925,   5.30477985],
#        [  3.29106736,   6.20874019],
#        [  0.09244751,  -5.5927165 ],
#        [ -5.59246069,   5.21612559],
#        [ -6.17559947,  -8.92661498],
#        [ -5.08759068,   5.35041694],
#        [  5.54072793,  -9.36239221],
#        [ -5.95679058,   5.62537049],
#        [ -6.92959277,  -8.41479682],
#        [ -0.5950974 ,  -6.47471693],
#        [ -0.22535085,  -4.87648022],
#        [  4.67225212,  -9.27466068],
#        [  2.38640802,   4.31585388],
#        [ -6.51550891,   5.50463454],
#        [ -1.03871908,  -5.23379673],
#        [  0.44370329,  -6.01522244],
#        [ -6.23947234,  -8.59790333],
#        [  1.52541303,   4.378113  ],
#        [  2.3529834 ,   5.13299291],
#        [ -6.7510342 ,  -8.31885012],
#        [ -6.52149685,  -8.01547852],
#        [ -6.36564753,  -7.83107004],
#        [  6.41895516,  -8.71255394],
#        [ -6.46750396,   5.0284752 ],
#        [  3.66565757,   5.69966045],
#        [ -0.44104355,  -6.29734297],
#        [ -6.07791793,  -8.46462416],
#        [ -0.40077217,  -4.95127952],
#        [  5.62651786,  -9.75377718],
#        [ -7.06337673,  -8.62454759],
#        [ -4.69878755,   4.65885318],
#        [ -0.53314403,  -5.6328339 ],
#        [  5.02411729,  -9.69130983],
#        [  2.78159727,   3.97888077],
#        [  0.52020493,  -5.22189083],
#        [  4.43754873, -10.45664716]])

# %%
y
# Out:
# array([1, 3, 4, 4, 0, 3, 4, 1, 4, 3, 3, 1, 1, 2, 2, 4, 4, 1, 1, 0, 1, 0,
#        4, 4, 3, 1, 2, 4, 3, 0, 3, 3, 3, 3, 0, 4, 1, 0, 3, 0, 3, 0, 0, 4,
#        0, 2, 1, 4, 1, 2, 3, 3, 2, 2, 0, 4, 0, 2, 3, 2, 1, 2, 0, 2, 0, 1,
#        1, 2, 4, 1, 3, 4, 2, 2, 1, 1, 2, 4, 1, 4, 2, 3, 2, 4, 4, 2, 2, 1,
#        3, 1, 0, 1, 3, 1, 1, 4, 3, 0, 3, 2, 4, 2, 4, 3, 1, 3, 0, 3, 0, 4,
#        1, 3, 4, 3, 3, 0, 0, 0, 3, 2, 2, 0, 1, 2, 0, 3, 3, 4, 1, 4, 0, 1,
#        0, 2, 1, 2, 0, 4, 2, 2, 1, 2, 4, 4, 1, 4, 1, 2, 2, 0, 4, 4, 0, 0,
#        1, 3, 3, 1, 0, 0, 0, 0, 0, 3, 3, 1, 2, 3, 4, 3, 0, 3, 4, 2, 2, 0,
#        1, 3, 2, 2, 4, 1, 1, 4, 4, 4, 0, 3, 1, 2, 4, 2, 0, 4, 3, 2, 0, 1,
#        2, 0])

# %%
plt.scatter(X[:, 0], X[:, 1], s=10)
plt.show()

# %%
blob_center = np.array([
    [ 0.2, 2.3],
    [-1.5, 2.3],
    [-2.8, 1.8],
    [-2.8, 2.8],
    [-2.8, 1.3]
])

blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])

X, y = make_blobs(
    n_samples=200,
    n_features=2,
    centers=blob_center,
    cluster_std=blob_std,
    random_state=0
)

plt.scatter(X[:, 0], X[:, 1], s=10)
plt.show()

# %%
K = 5

rng = np.random.default_rng(140)
centroids = rng.choice(X, size=K, replace=False)

plt.scatter(X[:, 0], X[:, 1], s=10)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=200)
plt.show()

# %%
centroids
# Out:
# array([[ 0.90562094,  2.46006288],
#        [-2.93342585,  2.66532825],
#        [-0.45207934,  2.4851129 ],
#        [-2.69003404,  1.86552637],
#        [-2.86878376,  1.17859226]])
