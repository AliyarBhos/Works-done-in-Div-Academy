# %%
import numpy as np
import pandas as pd

df = pd.read_csv(r'C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\housing.csv')

df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
outlier1 = df['housing_median_age'] == df['housing_median_age'].max()
outlier2 = df['median_house_value'] == df['median_house_value'].max()

df = df.loc[~outlier1 & ~outlier2, :]
df.head(2)

from sklearn.model_selection import train_test_split

X['income_cat'] = pd.cut(
    X['median_income'], 
    bins=[0,2,4,6,8,np.inf],
    labels=[1,2,3,4,5],
)

X_train, X_test, y_train, y_test = train_test_split(
    X,y,test_size=0.15,
    stratify=df['income_cat']
    )

X_train.drop('income_cat', axis='columns', inplace=True)
X_test.drop('income_cat', axis='columns', inplace=True)
X_train.shape , X_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       5 df.head(2)
#       7 from sklearn.model_selection import train_test_split
#       9 X['income_cat'] = pd.cut(
# ---> 10     X['median_income'],
#      11     bins=[0,2,4,6,8,np.inf],
#      12     labels=[1,2,3,4,5],
#      13 )
#      15 X_train, X_test, y_train, y_test = train_test_split(
#      16     X,y,test_size=0.15,
#      17     stratify=df['income_cat']
#      18     )
#      20 X_train.drop('income_cat', axis='columns', inplace=True)
#
# NameError: name 'X' is not defined
