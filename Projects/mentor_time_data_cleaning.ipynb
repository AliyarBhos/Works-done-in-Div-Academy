# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
path_to_csv = Path(r'C:\Users\konta\Documents\DIV_Academy\Module2(From_29_nov)\data\dirty_cafe_sales.csv')

# %%
df = pd.read_csv(path_to_csv)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df_copy = df

# %%
df_copy.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index   dtype  missing
# 0    Transaction ID  object        0
# 1              Item  object      333
# 2          Quantity  object      138
# 3    Price Per Unit  object      179
# 4       Total Spent  object      173
# 5    Payment Method  object     2579
# 6          Location  object     3265
# 7  Transaction Date  object      159

# %%
summary['missing_pct'] = (summary['missing'] / len(df_copy)) * 100
summary = summary.sort_values('missing_pct', ascending=False)
summary
# Out:
#               index   dtype  missing  missing_pct
# 6          Location  object     3265        32.65
# 5    Payment Method  object     2579        25.79
# 1              Item  object      333         3.33
# 3    Price Per Unit  object      179         1.79
# 4       Total Spent  object      173         1.73
# 7  Transaction Date  object      159         1.59
# 2          Quantity  object      138         1.38
# 0    Transaction ID  object        0         0.00

# %%
df_copy[df_copy['Location'].isna()]
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 5       TXN_2602893  Smoothie        5            4.0        20.0
# 16      TXN_3765707  Sandwich        1            4.0         4.0
# 23      TXN_2616390  Sandwich        2            4.0         8.0
# 28      TXN_8467949  Smoothie        5            4.0        20.0
# 30      TXN_1736287       NaN        5            2.0        10.0
# ...             ...       ...      ...            ...         ...
# 9993    TXN_4766549  Smoothie        2            4.0         NaN
# 9994    TXN_7851634   UNKNOWN        4            4.0        16.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
#
#       Payment Method Location Transaction Date
# 5        Credit Card      NaN       2023-03-31
# 16               NaN      NaN       2023-06-10
# ...

# %%
df_copy['Location'] = df_copy['Location'].fillna('No Location')

# %%
df_copy[df_copy['Location'].isna()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df_copy['Location'] = df_copy['Location'].replace('UNKNOWN', 'No Location')

# %%
df_copy[df_copy['Location'] == 'UNKNOWN']
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index   dtype  missing
# 0    Transaction ID  object        0
# 1              Item  object      333
# 2          Quantity  object      138
# 3    Price Per Unit  object      179
# 4       Total Spent  object      173
# 5    Payment Method  object     2579
# 6          Location  object        0
# 7  Transaction Date  object      159

# %%
summary['missing_pct'] = (summary['missing'] / len(df_copy)) * 100
summary = summary.sort_values('missing_pct', ascending=False)
summary
# Out:
#               index   dtype  missing  missing_pct
# 5    Payment Method  object     2579        25.79
# 1              Item  object      333         3.33
# 3    Price Per Unit  object      179         1.79
# 4       Total Spent  object      173         1.73
# 7  Transaction Date  object      159         1.59
# 2          Quantity  object      138         1.38
# 0    Transaction ID  object        0         0.00
# 6          Location  object        0         0.00

# %%
df_copy[df_copy['Payment Method'].isna()]
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8       TXN_4717867       NaN        5            3.0        15.0
# 9       TXN_2064365  Sandwich        5            4.0        20.0
# 13      TXN_9437049    Cookie        5            1.0         5.0
# 14      TXN_8915701     ERROR        2            1.5         3.0
# 16      TXN_3765707  Sandwich        1            4.0         4.0
# ...             ...       ...      ...            ...         ...
# 9978    TXN_4302199       Tea        3            1.5         4.5
# 9982    TXN_8567525    Cookie        2            1.0         2.0
# 9985    TXN_3297457      Cake        2            3.0         6.0
# 9994    TXN_7851634   UNKNOWN        4            4.0        16.0
# 9995    TXN_7672686    Coffee        2            2.0         4.0
#
#      Payment Method     Location Transaction Date
# 8               NaN     Takeaway       2023-07-28
# 9               NaN     In-store       2023-12-31
# ...

# %%
df_copy['Payment Method'] = df_copy['Payment Method'].fillna('No payment method')

# %%
df_copy[df_copy['Payment Method'].isna()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df_copy['Payment Method'] = df_copy['Payment Method'].replace('UNKNOWN', 'No payment method')

# %%
df_copy[df_copy['Payment Method'] == 'UNKNOWN']
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index   dtype  missing
# 0    Transaction ID  object        0
# 1              Item  object      333
# 2          Quantity  object      138
# 3    Price Per Unit  object      179
# 4       Total Spent  object      173
# 5    Payment Method  object        0
# 6          Location  object        0
# 7  Transaction Date  object      159

# %%
summary['missing_pct'] = (summary['missing'] / len(df_copy)) * 100
summary = summary.sort_values('missing_pct', ascending=False)
summary
# Out:
#               index   dtype  missing  missing_pct
# 1              Item  object      333         3.33
# 3    Price Per Unit  object      179         1.79
# 4       Total Spent  object      173         1.73
# 7  Transaction Date  object      159         1.59
# 2          Quantity  object      138         1.38
# 0    Transaction ID  object        0         0.00
# 5    Payment Method  object        0         0.00
# 6          Location  object        0         0.00

# %%
df_copy['Item']
# Out:
# 0         Coffee
# 1           Cake
# 2         Cookie
# 3          Salad
# 4         Coffee
#           ...
# 9995      Coffee
# 9996         NaN
# 9997      Coffee
# 9998      Cookie
# 9999    Sandwich
# Name: Item, Length: 10000, dtype: object

# %%
df_copy[df_copy['Item'].isna()]
# Out:
#      Transaction ID Item Quantity Price Per Unit Total Spent  \
# 8       TXN_4717867  NaN        5            3.0        15.0
# 30      TXN_1736287  NaN        5            2.0        10.0
# 61      TXN_8051289  NaN        1            3.0         3.0
# 72      TXN_6044979  NaN        1            1.0         1.0
# 89      TXN_4132730  NaN        5            1.0         5.0
# ...             ...  ...      ...            ...         ...
# 9820    TXN_8751702  NaN        5            NaN        15.0
# 9855    TXN_3740505  NaN        2            1.5         3.0
# 9876    TXN_3105633  NaN        1            2.0         2.0
# 9885    TXN_4659954  NaN        3            4.0        12.0
# 9996    TXN_9659401  NaN        3            NaN         3.0
#
#          Payment Method     Location Transaction Date
# 8     No payment method     Takeaway       2023-07-28
# 30       Digital Wallet  No Location       2023-06-02
# 61    No payment method     In-store       2023-10-09
# ...

# %%
df_copy['Item'] = df_copy['Item'].fillna('Unwritten Item')

# %%
df_copy
# Out:
#      Transaction ID            Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373          Coffee        2            2.0         4.0
# 1       TXN_4977031            Cake        4            3.0        12.0
# 2       TXN_4271903          Cookie        4            1.0       ERROR
# 3       TXN_7034554           Salad        2            5.0        10.0
# 4       TXN_3160411          Coffee        2            2.0         4.0
# ...             ...             ...      ...            ...         ...
# 9995    TXN_7672686          Coffee        2            2.0         4.0
# 9996    TXN_9659401  Unwritten Item        3            NaN         3.0
# 9997    TXN_5255387          Coffee        4            2.0         8.0
# 9998    TXN_7695629          Cookie        3            NaN         3.0
# 9999    TXN_6170729        Sandwich        3            4.0        12.0
#
#          Payment Method     Location Transaction Date
# ...

# %%
df_copy[df_copy['Item'] == 'ERROR']
# Out:
#      Transaction ID   Item Quantity Price Per Unit Total Spent  \
# 14      TXN_8915701  ERROR        2            1.5         3.0
# 69      TXN_8471743  ERROR        5            3.0        15.0
# 88      TXN_9487821  ERROR        1            5.0         5.0
# 118     TXN_4633784  ERROR        5            NaN        15.0
# 211     TXN_6717827  ERROR        3            5.0        15.0
# ...             ...    ...      ...            ...         ...
# 9910    TXN_2338617  ERROR        2            3.0         6.0
# 9918    TXN_2292088  ERROR        1            4.0         4.0
# 9951    TXN_4122925  ERROR        4            1.0         4.0
# 9958    TXN_4125474  ERROR        2            5.0        10.0
# 9981    TXN_4583012  ERROR        5            4.0        20.0
#
#          Payment Method     Location Transaction Date
# 14    No payment method     In-store       2023-03-21
# 69       Digital Wallet     In-store       2023-04-06
# ...

# %%
df_copy['Item'] = df_copy['Item'].replace('UNKNOWN', 'Unwritten Item')

# %%
df_copy['Item'] = df_copy['Item'].replace('ERROR', 'Unwritten Item')

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index   dtype  missing
# 0    Transaction ID  object        0
# 1              Item  object        0
# 2          Quantity  object      138
# 3    Price Per Unit  object      179
# 4       Total Spent  object      173
# 5    Payment Method  object        0
# 6          Location  object        0
# 7  Transaction Date  object      159

# %%
summary['missing_pct'] = (summary['missing'] / len(df_copy)) * 100
summary = summary.sort_values('missing_pct', ascending=False)
summary
# Out:
#               index   dtype  missing  missing_pct
# 3    Price Per Unit  object      179         1.79
# 4       Total Spent  object      173         1.73
# 7  Transaction Date  object      159         1.59
# 2          Quantity  object      138         1.38
# 0    Transaction ID  object        0         0.00
# 1              Item  object        0         0.00
# 5    Payment Method  object        0         0.00
# 6          Location  object        0         0.00

# %%
df_copy[df_copy['Price Per Unit'].isna()]
# Out:
#      Transaction ID            Item Quantity Price Per Unit Total Spent  \
# 56      TXN_3578141            Cake        5            NaN        15.0
# 65      TXN_4987129        Sandwich        3            NaN         NaN
# 85      TXN_8035512             Tea        3            NaN         4.5
# 104     TXN_7447872           Juice        2            NaN         6.0
# 118     TXN_4633784  Unwritten Item        5            NaN        15.0
# ...             ...             ...      ...            ...         ...
# 9820    TXN_8751702  Unwritten Item        5            NaN        15.0
# 9893    TXN_3809533           Juice        2            NaN       ERROR
# 9924    TXN_5981429           Juice        2            NaN         6.0
# 9996    TXN_9659401  Unwritten Item        3            NaN         3.0
# 9998    TXN_7695629          Cookie        3            NaN         3.0
#
#          Payment Method     Location Transaction Date
# ...

# %%
df_copy[df_copy['Price Per Unit'] == 'ERROR']
# Out:
#      Transaction ID            Item Quantity Price Per Unit Total Spent  \
# 68      TXN_8427104           Salad        2          ERROR        10.0
# 196     TXN_3800182             Tea        2          ERROR         3.0
# 212     TXN_9089898           Salad        3          ERROR        15.0
# 213     TXN_8587583            Cake        1          ERROR         3.0
# 289     TXN_3495950  Unwritten Item        4          ERROR         6.0
# ...             ...             ...      ...            ...         ...
# 9533    TXN_4434185        Smoothie        5          ERROR        20.0
# 9605    TXN_9397870            Cake        2          ERROR         6.0
# 9649    TXN_2509803          Coffee        1          ERROR         2.0
# 9717    TXN_3334632  Unwritten Item        1          ERROR         2.0
# 9753    TXN_3507013           Juice        1          ERROR         3.0
#
#          Payment Method     Location Transaction Date
# ...

# %%
df_copy[df_copy['Price Per Unit'] == 'UNKNOWN']
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 140     TXN_2484241      Cake        3        UNKNOWN         9.0
# 147     TXN_9336980     Salad        4        UNKNOWN        20.0
# 161     TXN_7965998     Juice        1        UNKNOWN         3.0
# 162     TXN_9238666    Cookie        1        UNKNOWN         1.0
# 228     TXN_9350833      Cake        1        UNKNOWN         3.0
# ...             ...       ...      ...            ...         ...
# 9742    TXN_8077812     Salad        5        UNKNOWN        25.0
# 9755    TXN_3092390  Sandwich        3        UNKNOWN        12.0
# 9796    TXN_8191202    Cookie        2        UNKNOWN         2.0
# 9926    TXN_2464706      Cake        4        UNKNOWN        12.0
# 9961    TXN_2153100       Tea        2        UNKNOWN         3.0
#
#          Payment Method     Location Transaction Date
# 140      Digital Wallet  No Location       2023-07-19
# 147                Cash     In-store       2023-06-06
# ...

# %%
df_copy['Price Per Unit'] = df_copy['Price Per Unit'].replace('UNKNOWN', 0)

# %%
df_copy['Price Per Unit'] = df_copy['Price Per Unit'].replace('ERROR', 0)

# %%
df_copy['Price Per Unit'] = df_copy['Price Per Unit'].fillna(0)

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index   dtype  missing
# 0    Transaction ID  object        0
# 1              Item  object        0
# 2          Quantity  object      138
# 3    Price Per Unit  object        0
# 4       Total Spent  object      173
# 5    Payment Method  object        0
# 6          Location  object        0
# 7  Transaction Date  object      159

# %%
summary['missing_pct'] = (summary['missing'] / len(df_copy)) * 100
summary = summary.sort_values('missing_pct', ascending=False)
summary
# Out:
#               index   dtype  missing  missing_pct
# 4       Total Spent  object      173         1.73
# 7  Transaction Date  object      159         1.59
# 2          Quantity  object      138         1.38
# 0    Transaction ID  object        0         0.00
# 3    Price Per Unit  object        0         0.00
# 1              Item  object        0         0.00
# 5    Payment Method  object        0         0.00
# 6          Location  object        0         0.00

# %%
df_copy['Total Spent'] = df_copy['Total Spent'].fillna(0)

# %%
df_copy['Total Spent'] = df_copy['Total Spent'].replace('UNKNOWN', 0)

# %%
df_copy['Total Spent'] = df_copy['Total Spent'].replace('ERROR', 0)

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index   dtype  missing
# 0    Transaction ID  object        0
# 1              Item  object        0
# 2          Quantity  object      138
# 3    Price Per Unit  object        0
# 4       Total Spent  object        0
# 5    Payment Method  object        0
# 6          Location  object        0
# 7  Transaction Date  object      159

# %%
summary['missing_pct'] = (summary['missing'] / len(df_copy)) * 100
summary = summary.sort_values('missing_pct', ascending=False)
summary
# Out:
#               index   dtype  missing  missing_pct
# 7  Transaction Date  object      159         1.59
# 2          Quantity  object      138         1.38
# 1              Item  object        0         0.00
# 0    Transaction ID  object        0         0.00
# 3    Price Per Unit  object        0         0.00
# 4       Total Spent  object        0         0.00
# 5    Payment Method  object        0         0.00
# 6          Location  object        0         0.00

# %%
df_copy['Quantity'] = df_copy['Quantity'].fillna(0)

# %%
df_copy['Quantity'] = df_copy['Quantity'].replace('UNKNOWN', 0)

# %%
df_copy['Quantity'] = df_copy['Quantity'].replace('ERROR', 0)

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index   dtype  missing
# 0    Transaction ID  object        0
# 1              Item  object        0
# 2          Quantity  object        0
# 3    Price Per Unit  object        0
# 4       Total Spent  object        0
# 5    Payment Method  object        0
# 6          Location  object        0
# 7  Transaction Date  object      159

# %%
summary['missing_pct'] = (summary['missing'] / len(df_copy)) * 100
summary = summary.sort_values('missing_pct', ascending=False)
summary
# Out:
#               index   dtype  missing  missing_pct
# 7  Transaction Date  object      159         1.59
# 0    Transaction ID  object        0         0.00
# 2          Quantity  object        0         0.00
# 1              Item  object        0         0.00
# 3    Price Per Unit  object        0         0.00
# 4       Total Spent  object        0         0.00
# 5    Payment Method  object        0         0.00
# 6          Location  object        0         0.00

# %%
df_copy['Quantity'] = df_copy['Quantity'].astype('float')

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index    dtype  missing
# 0    Transaction ID   object        0
# 1              Item   object        0
# 2          Quantity  float64        0
# 3    Price Per Unit   object        0
# 4       Total Spent   object        0
# 5    Payment Method   object        0
# 6          Location   object        0
# 7  Transaction Date   object      159

# %%
df_copy['Total Spent'] = df_copy['Total Spent'].astype('float')

# %%
df_copy['Price Per Unit'] = df_copy['Price Per Unit'].astype('float')

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index    dtype  missing
# 0    Transaction ID   object        0
# 1              Item   object        0
# 2          Quantity  float64        0
# 3    Price Per Unit  float64        0
# 4       Total Spent  float64        0
# 5    Payment Method   object        0
# 6          Location   object        0
# 7  Transaction Date   object      159

# %%
df_copy['Price Per Unit'] = df_copy['Price Per Unit'].fillna(df_copy['Total Spent'] / df_copy['Quantity'])

# %%
df_copy['Quantity'] = df_copy['Quantity'].fillna(df_copy['Total Spent'] / df_copy['Price Per Unit'])

# %%
df_copy['Total Spent'] = df_copy['Quantity'].fillna(df_copy['Quantity'] * df_copy['Price Per Unit'])

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index    dtype  missing
# 0    Transaction ID   object        0
# 1              Item   object        0
# 2          Quantity  float64        0
# 3    Price Per Unit  float64        0
# 4       Total Spent  float64        0
# 5    Payment Method   object        0
# 6          Location   object        0
# 7  Transaction Date   object      159

# %%
df_copy['Transaction Date'] = df_copy['Transaction Date'].fillna('No Date')

# %%
df_copy['Transaction Date'] = df_copy['Transaction Date'].replace('ERROR', 'No Date')

# %%
df_copy['Transaction Date'] = df_copy['Transaction Date'].replace('UNKNOWN', 'No Date')

# %%
summary = pd.DataFrame({
    "dtype": df_copy.dtypes,
    "missing": df_copy.isnull().sum()
}).reset_index()

summary
# Out:
#               index    dtype  missing
# 0    Transaction ID   object        0
# 1              Item   object        0
# 2          Quantity  float64        0
# 3    Price Per Unit  float64        0
# 4       Total Spent  float64        0
# 5    Payment Method   object        0
# 6          Location   object        0
# 7  Transaction Date   object        0

# %%
df_copy.to_csv('Cleaned_Coffee_Ugly_Data.csv')
